# %% [markdown]
# # Can we make a change on climate change?
# #### EPA1333 Final Assignment
#
# #### Angga Irawan (4516974), Priadi Teguh Wibowo (4625862)

# %% [markdown]
# # Introduction
#
# Global temperature rise, warming oceans, shrinking ice sheets, sea level rise are some evidences that the climate is changing. The suspected main cause of this phenomena is the greenhouse effect generated by the certain type of gases such as, Nitrous oxide, Carbon dioxide, and Methane.
#
# The long term consequences of this phenomena will affect the future condition of the Earth. Temperature will continue to increase, changes of precipitation patterns, also potentially more heat waves and hurricanes.
#
# In this project assignment, we are going to try to inspect a data mainly from World Bank data, take a closer look to the data and build a model of the climate change phenomena to foresee what is going to happen in the near future if we do not change the current trend or stay at our current state of environment system.
#
# We will restrict our investigation to one of the most prominent evidence of the climate change: Global Temperature, global surface temperature anomaly to be more precise. It refers to the deviation of the observed temperature from the reference or long term average. This observation can be used as diagnostic quantity of global-scale climate [1].
#
# We will analyse the dataset provided, perform a preliminary investigation to get a better understanding of the data and obtain the initial insight. We also will add the dataset with the information from another resources, do a selection of the appropiate information, and preprocess the data so that the data will not completely raw.
#
# Then, we could manipulate the data to form a so called features matrix and target vector and develop a model by using the various machine learning algorithm.
#
# Furthermore, we could perform a prediction of the future condition and explore more the parameter of the model so that we get a better explanation why the condition turn to be so.

# %% [markdown]
# <dl>
# The following are several research questions we are going to try to answer to help our analysis keep on track.
# <dd>1. Since when the climate change 'effectively' causing the global temperature anomaly to be warmer than the reference (1951-1980 average temperatures)? </dd>
# <dd>2. Which factors is contributing the most to global temperature anomaly?</dd>
# <dd>3. What will happen to global temperature anomaly if we do not change the trend of the current condition? </dd>
# </dl>
#
# [1] https://www.ncdc.noaa.gov/monitoring-references/faq/anomalies.php

# %% [markdown]
# # Data
#
# ## Climate change indicators
# The climate change data offered by World Bank contains a large set of indicators, such as for example CO2 emissions, population growth or renewable energy output. Values of these indicators are available per country and per year. The data is available in this URL: https://data.worldbank.org/topic/climate-change. It is also complemented by two files of metadata.

# %% [markdown]
# Import standard library to prepare the reading and loading process of the data.

# %%
# import standard library
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# Load the World Bank data as a dataframe.

# %%
# load world bank data
# skip the unneeded header
wb = pd.read_csv('world_bank/API_19_DS2_en_csv_v2.csv', sep=',', header=0, skiprows=3) 

# read_csv resulted in additional blank series at the last column -> drop the column
wb = wb.drop(wb.columns[[-1]], 1)

# display the head of dataframe
print("Dataframe shape:", wb.shape)
wb.head()
# Out:
# Dataframe shape: (21120, 61)
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW       Urban population (% of total)
# 1        Aruba          ABW                    Urban population
# 2        Aruba          ABW  Urban population growth (annual %)
# 3        Aruba          ABW                   Population, total
# 4        Aruba          ABW        Population growth (annual %)
#
#       Indicator Code          1960          1961          1962          1963  \
# 0  SP.URB.TOTL.IN.ZS     50.776000     50.761000     50.746000     50.730000
# 1        SP.URB.TOTL  27526.000000  28141.000000  28532.000000  28761.000000
# 2        SP.URB.GROW      3.117931      2.209658      1.379868      0.799404
# 3        SP.POP.TOTL  54211.000000  55438.000000  56225.000000  56695.000000
# 4        SP.POP.GROW      3.148037      2.238144      1.409622      0.832453
#
#            1964          1965      ...                 2007           2008  \
# 0     50.715000     50.700000      ...            44.147000      43.783000
# 1  28924.000000  29082.000000      ...         44686.000000   44375.000000
# 2      0.565140      0.544773      ...            -0.435429      -0.698401
# 3  57032.000000  57360.000000      ...        101220.000000  101353.000000
# 4      0.592649      0.573468      ...             0.384060       0.131311
#
#             2009           2010           2011           2012           2013  \
# 0      43.421000      43.059000      42.698000      42.364000      42.058000
# 1   44052.000000   43778.000000   43575.000000   43456.000000   43398.000000
# 2      -0.730549      -0.623935      -0.464782      -0.273466      -0.133557
# 3  101453.000000  101669.000000  102053.000000  102577.000000  103187.000000
# 4       0.098616       0.212680       0.376985       0.512145       0.592914
#
#             2014           2015           2016
# 0      41.779000      41.528000      41.304000
# 1   43365.000000   43331.000000   43296.000000
# 2      -0.076069      -0.078435      -0.080806
# 3  103795.000000  104341.000000  104822.000000
# 4       0.587492       0.524658       0.459929
#
# [5 rows x 61 columns]

# %% [markdown]
# The World Bank data consists of data for 57 years (1960-2016) of 264 countries with 80 indicators for each country. These data could be utilized as the initial data.

# %% [markdown]
# ### Countries Metadata

# %% [markdown]
# Load the additional csv file which contains the metadata of the countries on the main World Bank data.

# %%
#load country metadata
wb_meta_country = pd.read_csv('world_bank/Metadata_Country_API_19_DS2_en_csv_v2.csv', sep=',', header=0) 

# read_csv resulted in additional blank series at the last column -> drop the column
wb_meta_country = wb_meta_country.drop(wb_meta_country.columns[[-1]], 1)

# display the head of dataframe
wb_meta_country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName
# 0  SNA data for 2000-2011 are updated from offici...        Aruba
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan
# 2                                                NaN       Angola
# 3                                                NaN      Albania
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra

# %% [markdown]
# ### Indicator Metadata

# %% [markdown]
# We also have to include the another csv file containing the metadata of the indicator on the main World Bank data.

# %%
#load indicator metadata
wb_meta_indi = pd.read_csv('world_bank/Metadata_Indicator_API_19_DS2_en_csv_v2.csv', sep=',', header=0) 

# read_csv resulted in additional blank series at the last column -> drop the column
wb_meta_indi = wb_meta_indi.drop(wb_meta_indi.columns[[-1]], 1)

# display the head of dataframe
wb_meta_indi.head()
# Out:
#       INDICATOR_CODE                      INDICATOR_NAME  \
# 0  SP.URB.TOTL.IN.ZS       Urban population (% of total)
# 1        SP.URB.TOTL                    Urban population
# 2        SP.URB.GROW  Urban population growth (annual %)
# 3        SP.POP.TOTL                   Population, total
# 4        SP.POP.GROW        Population growth (annual %)
#
#                                          SOURCE_NOTE  \
# 0  Urban population refers to people living in ur...
# 1  Urban population refers to people living in ur...
# 2  Urban population refers to people living in ur...
# 3  Total population is based on the de facto defi...
# 4  Annual population growth rate for year t is th...
#
#                                  SOURCE_ORGANIZATION
# 0  The United Nations Population Divisions World ...
# 1  World Bank Staff estimates based on United Nat...
# 2  World Bank Staff estimates based on United Nat...
# 3  (1) United Nations Population Division. World ...
# 4  Derived from total population. Population sour...

# %% [markdown]
# # Additional Data

# %% [markdown]
# We need additional data from other resources to assist the previous obtained data as the additional feature, a potential label/output for the classification/regression, or a ground truth for the prediction.

# %% [markdown]
# ## Global Temperature Anomaly
#
# Global Temperature Anomaly data is provided by NASA, https://climate.nasa.gov/vital-signs/global-temperature/. This graph below illustrates the change in global surface temperature relative to 1951-1980 average temperatures. Sixteen of the 17 warmest years in the 136-year record all have occurred since 2001, with the exception of 1998. The year 2016 ranks as the warmest on record.
#
# Later, the global temperature anomaly from 1960 to 2016 will be used as target vector or output to be fitted in model.

# %%
df_tempe = pd.read_csv(
    'https://climate.nasa.gov/system/internal_resources/details/original/647_Global_Temperature_Data_File.txt', 
    sep="     ", 
    names=['year', 'annual mean', '5 year mean'],
    index_col = 'year',
    engine ='python')

# %%
df_tempe.plot(figsize = (16,5))
plt.ylabel('Temperature Anomaly (C)')
plt.title('Temperature Anomaly')

# %%
# slice the range of year, make suitable with the world bank data (provided since 1960)
df_tempe.index.name = None
df_tempe_since_1960 = df_tempe[80:]
df_tempe_since_1960.head()
# Out:
#       annual mean  5 year mean
# 1960        -0.02         0.03
# 1961         0.05         0.02
# 1962         0.03        -0.01
# 1963         0.06        -0.02
# 1964        -0.20        -0.03

# %% [markdown]
# ## Global Warming

# %% [markdown]
# We could find the start of the global warming approximately from the 5 years mean data when the anomaly is continuously higher than the temperature reference.

# %%
def strictly_increasing(L):
    return all(x<y for x, y in zip(L, L[1:]))

# %%
l = list(df_tempe[(df_tempe['5 year mean'] > 0)]['5 year mean'])
strictly_increasing(l)
# Out:
# False

# %% [markdown]
# ## Climate Change Performance Index
#
# Climate Change Performance Index (CCPI) is issued by Germanwatch and Climate Action Network Europe, https://germanwatch.org/en/13042. For the past 12 years, it has been keep tracking various countries’ efforts in combating climate change. On the basis of standardised criteria, the index evaluates and compares the climate protection performance of 58 countries that together are responsible for about 90% of global energy-related CO2 emissions. Unfortunately, we have to delete Taipei from the list as the World Bank data does not provide the data for the country.
#
# This data can be used to filter out the raw data / World Bank data with only countries that has most contribution to CO2 emission.

# %%
# load label Climate Change Performance Index
ccpi_country = pd.read_csv('CCPI/CCPI_2017.csv', sep=',', header=0) 

# rename the CCPI column to Country Name, so it could be 'merge' on this column name
ccpi_country.columns = ['Country Name', 'Category']
ccpi_country.head()
# Out:
#      Country Name Category
# 0          France     Good
# 1          Sweden     Good
# 2  United Kingdom     Good
# 3          Cyprus     Good
# 4         Morocco     Good

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Before jump in to the analysis of the data, we need to clean and preprocess the data first.

# %% [markdown]
# ## World Bank Data Interpolation

# %% [markdown]
# Many missing data are found in World Bank raw data. Thus, interpolation is performed to fill those missing data with appropriate values. We need to drop header and indicator of the dataframe so that we create a temporary dataframe with only numerical value of the World Bank data. We need this transformation to accomplish the interpolation.

# %%
# create column of years of the world bank data
years_column = wb.columns.values[range(4,61)]
years_column

# copy the content of the dataframe (to avoid copying the reference) for the interpolation
wb_prep = pd.DataFrame()
wb_prep = wb[years_column]

# reset the column (year) to integer
wb_prep.columns = range(0,57)

# display the dataframe
wb_prep.head(8)
# Out:
#              0             1             2             3             4   \
# 0     50.776000     50.761000     50.746000     50.730000     50.715000
# 1  27526.000000  28141.000000  28532.000000  28761.000000  28924.000000
# 2      3.117931      2.209658      1.379868      0.799404      0.565140
# 3  54211.000000  55438.000000  56225.000000  56695.000000  57032.000000
# 4      3.148037      2.238144      1.409622      0.832453      0.592649
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
#
#              5             6             7             8             9   \
# 0     50.700000     50.685000     50.670000     50.654000     50.639000
# 1  29082.000000  29253.000000  29416.000000  29575.000000  29738.000000
# 2      0.544773      0.586271      0.555661      0.539067      0.549628
# 3  57360.000000  57715.000000  58055.000000  58386.000000  58726.000000
# 4      0.573468      0.616991      0.587373      0.568530      0.580642
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
#
#        ...                   47             48             49             50  \
# 0      ...            44.147000      43.783000      43.421000      43.059000
# 1      ...         44686.000000   44375.000000   44052.000000   43778.000000
# 2      ...            -0.435429      -0.698401      -0.730549      -0.623935
# 3      ...        101220.000000  101353.000000  101453.000000  101669.000000
# 4      ...             0.384060       0.131311       0.098616       0.212680
# 5      ...                  NaN            NaN            NaN            NaN
# 6      ...                  NaN            NaN            NaN            NaN
# 7      ...            97.900000      97.800000      97.800000      97.700000
#
#               51             52             53             54             55  \
# 0      42.698000      42.364000      42.058000      41.779000      41.528000
# 1   43575.000000   43456.000000   43398.000000   43365.000000   43331.000000
# 2      -0.464782      -0.273466      -0.133557      -0.076069      -0.078435
# 3  102053.000000  102577.000000  103187.000000  103795.000000  104341.000000
# 4       0.376985       0.512145       0.592914       0.587492       0.524658
# 5            NaN            NaN            NaN            NaN            NaN
# 6            NaN            NaN            NaN            NaN            NaN
# 7      97.700000      97.700000      97.700000      97.700000      97.700000
#
#               56
# 0      41.304000
# 1   43296.000000
# 2      -0.080806
# 3  104822.000000
# 4       0.459929
# 5            NaN
# 6            NaN
# 7            NaN
#
# [8 rows x 57 columns]

# %% [markdown]
# As we can see from dataframe above, we have a particular row with NaN as its value, both partially or fully for entire row. We will perform the interpolation only to the partial one, see row 7 for an example.

# %%
# interpolate the data in row direction also in both direction within range limit
wb_interpolated = wb_prep.interpolate(method='linear',limit_direction='both',limit=56,axis=1)

# %%
# show the interpolation results
wb_interpolated.head(8)
# Out:
#              0             1             2             3             4   \
# 0     50.776000     50.761000     50.746000     50.730000     50.715000
# 1  27526.000000  28141.000000  28532.000000  28761.000000  28924.000000
# 2      3.117931      2.209658      1.379868      0.799404      0.565140
# 3  54211.000000  55438.000000  56225.000000  56695.000000  57032.000000
# 4      3.148037      2.238144      1.409622      0.832453      0.592649
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7     98.600000     98.600000     98.600000     98.600000     98.600000
#
#              5             6             7             8             9   \
# 0     50.700000     50.685000     50.670000     50.654000     50.639000
# 1  29082.000000  29253.000000  29416.000000  29575.000000  29738.000000
# 2      0.544773      0.586271      0.555661      0.539067      0.549628
# 3  57360.000000  57715.000000  58055.000000  58386.000000  58726.000000
# 4      0.573468      0.616991      0.587373      0.568530      0.580642
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7     98.600000     98.600000     98.600000     98.600000     98.600000
#
#        ...                   47             48             49             50  \
# 0      ...            44.147000      43.783000      43.421000      43.059000
# 1      ...         44686.000000   44375.000000   44052.000000   43778.000000
# 2      ...            -0.435429      -0.698401      -0.730549      -0.623935
# 3      ...        101220.000000  101353.000000  101453.000000  101669.000000
# 4      ...             0.384060       0.131311       0.098616       0.212680
# 5      ...                  NaN            NaN            NaN            NaN
# 6      ...                  NaN            NaN            NaN            NaN
# 7      ...            97.900000      97.800000      97.800000      97.700000
#
#               51             52             53             54             55  \
# 0      42.698000      42.364000      42.058000      41.779000      41.528000
# 1   43575.000000   43456.000000   43398.000000   43365.000000   43331.000000
# 2      -0.464782      -0.273466      -0.133557      -0.076069      -0.078435
# 3  102053.000000  102577.000000  103187.000000  103795.000000  104341.000000
# 4       0.376985       0.512145       0.592914       0.587492       0.524658
# 5            NaN            NaN            NaN            NaN            NaN
# 6            NaN            NaN            NaN            NaN            NaN
# 7      97.700000      97.700000      97.700000      97.700000      97.700000
#
#               56
# 0      41.304000
# 1   43296.000000
# 2      -0.080806
# 3  104822.000000
# 4       0.459929
# 5            NaN
# 6            NaN
# 7      97.700000
#
# [8 rows x 57 columns]

# %% [markdown]
# The row now are filled out by values from the interpolation results. As for the case where the entire row is completely fill out by NaN, we will handle it later.

# %% [markdown]
# A new dataframe is created to accomodate the new interpolated values.

# %%
# create a new dataframe to avoid overwriting the original dataframe
wb_inter = pd.DataFrame()
wb_inter = wb[wb.columns.values]

# replace wb_inter annual value with the interpolated one
wb_inter[list(wb.columns.values[range(4,61)])] = wb_interpolated[list(range(0,57))]

# now we have interpolated world bank data
wb_inter.head(8)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
# 5        Aruba          ABW
# 6        Aruba          ABW
# 7        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0                      Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 1                                   Urban population        SP.URB.TOTL
# 2                 Urban population growth (annual %)        SP.URB.GROW
# 3                                  Population, total        SP.POP.TOTL
# 4                       Population growth (annual %)        SP.POP.GROW
# 5  Poverty headcount ratio at $1.90 a day (2011 P...        SI.POV.DDAY
# 6  Prevalence of underweight, weight for age (% o...     SH.STA.MALN.ZS
# 7  Improved sanitation facilities (% of populatio...        SH.STA.ACSN
#
#            1960          1961          1962          1963          1964  \
# 0     50.776000     50.761000     50.746000     50.730000     50.715000
# 1  27526.000000  28141.000000  28532.000000  28761.000000  28924.000000
# 2      3.117931      2.209658      1.379868      0.799404      0.565140
# 3  54211.000000  55438.000000  56225.000000  56695.000000  57032.000000
# 4      3.148037      2.238144      1.409622      0.832453      0.592649
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7     98.600000     98.600000     98.600000     98.600000     98.600000
#
#            1965      ...                 2007           2008           2009  \
# 0     50.700000      ...            44.147000      43.783000      43.421000
# 1  29082.000000      ...         44686.000000   44375.000000   44052.000000
# 2      0.544773      ...            -0.435429      -0.698401      -0.730549
# 3  57360.000000      ...        101220.000000  101353.000000  101453.000000
# 4      0.573468      ...             0.384060       0.131311       0.098616
# 5           NaN      ...                  NaN            NaN            NaN
# 6           NaN      ...                  NaN            NaN            NaN
# 7     98.600000      ...            97.900000      97.800000      97.800000
#
#             2010           2011           2012           2013           2014  \
# 0      43.059000      42.698000      42.364000      42.058000      41.779000
# 1   43778.000000   43575.000000   43456.000000   43398.000000   43365.000000
# 2      -0.623935      -0.464782      -0.273466      -0.133557      -0.076069
# 3  101669.000000  102053.000000  102577.000000  103187.000000  103795.000000
# 4       0.212680       0.376985       0.512145       0.592914       0.587492
# 5            NaN            NaN            NaN            NaN            NaN
# 6            NaN            NaN            NaN            NaN            NaN
# 7      97.700000      97.700000      97.700000      97.700000      97.700000
#
#             2015           2016
# 0      41.528000      41.304000
# 1   43331.000000   43296.000000
# 2      -0.078435      -0.080806
# 3  104341.000000  104822.000000
# 4       0.524658       0.459929
# 5            NaN            NaN
# 6            NaN            NaN
# 7      97.700000      97.700000
#
# [8 rows x 61 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Filter the World Bank data with CCPI countries

# %% [markdown]
# New dataframe which contains only the data from countries being mentioned in CCPI document is created.

# %%
# create a df of countries from CCPI results countries
df_ccpi = pd.DataFrame()
for country in ccpi_country['Country Name']:
    # filter the CCPI countries
    
    # not interpolated
    # df1 = wb[wb['Country Name'] == country]
    
    # take it from the interpolated one
    df1 = wb_inter[wb_inter['Country Name'] == country]

    # append to the df
    df_ccpi = pd.concat( [df_ccpi,df1], ignore_index=True, axis=0)
    
df_ccpi[:8]
# Out:
#   Country Name Country Code  \
# 0       France          FRA
# 1       France          FRA
# 2       France          FRA
# 3       France          FRA
# 4       France          FRA
# 5       France          FRA
# 6       France          FRA
# 7       France          FRA
#
#                                       Indicator Name     Indicator Code  \
# 0                      Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 1                                   Urban population        SP.URB.TOTL
# 2                 Urban population growth (annual %)        SP.URB.GROW
# 3                                  Population, total        SP.POP.TOTL
# 4                       Population growth (annual %)        SP.POP.GROW
# 5  Poverty headcount ratio at $1.90 a day (2011 P...        SI.POV.DDAY
# 6  Prevalence of underweight, weight for age (% o...     SH.STA.MALN.ZS
# 7  Improved sanitation facilities (% of populatio...        SH.STA.ACSN
#
#            1960          1961          1962          1963          1964  \
# 0  6.188000e+01  6.260700e+01  6.348900e+01  6.470200e+01  6.589800e+01
# 1  2.896865e+07  2.970374e+07  3.055068e+07  3.157696e+07  3.258617e+07
# 2  2.424503e+00  2.505858e+00  2.811428e+00  3.304057e+00  3.146026e+00
# 3  4.681424e+07  4.744475e+07  4.811965e+07  4.880368e+07  4.944940e+07
# 4  1.229610e+00  1.337853e+00  1.412470e+00  1.411512e+00  1.314427e+00
# 5  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01
# 6           NaN           NaN           NaN           NaN           NaN
# 7  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01
#
#            1965      ...               2007          2008          2009  \
# 0  6.707100e+01      ...       7.762100e+01  7.786400e+01  7.810600e+01
# 1  3.355144e+07      ...       4.969004e+07  5.012494e+07  5.054008e+07
# 2  2.919203e+00      ...       9.335545e-01  8.714278e-01  8.248035e-01
# 3  5.002377e+07      ...       6.401623e+07  6.437499e+07  6.470704e+07
# 4  1.154839e+00      ...       6.187115e-01  5.588574e-01  5.144864e-01
# 5  1.000000e-01      ...       0.000000e+00  0.000000e+00  5.000000e-02
# 6           NaN      ...                NaN           NaN           NaN
# 7  9.870000e+01      ...       9.870000e+01  9.870000e+01  9.870000e+01
#
#            2010          2011          2012          2013          2014  \
# 0  7.834500e+01  7.858400e+01  7.882000e+01  7.905500e+01  7.928900e+01
# 1  5.094580e+07  5.134897e+07  5.175305e+07  5.217517e+07  5.259394e+07
# 2  7.995637e-01  7.882418e-01  7.838471e-01  8.123421e-01  7.994288e-01
# 3  6.502751e+07  6.534278e+07  6.565979e+07  6.599857e+07  6.633196e+07
# 4  4.940375e-01  4.836449e-01  4.839823e-01  5.146361e-01  5.038712e-01
# 5  1.000000e-01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 6           NaN           NaN           NaN           NaN           NaN
# 7  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01
#
#            2015          2016
# 0  7.952000e+01  7.975000e+01
# 1  5.297946e+07  5.334965e+07
# 2  7.303273e-01  6.963089e-01
# 3  6.662407e+07  6.689611e+07
# 4  4.394107e-01  4.074910e-01
# 5  0.000000e+00  0.000000e+00
# 6           NaN           NaN
# 7  9.870000e+01  9.870000e+01
#
# [8 rows x 61 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Removing Missing Indicator (NaN for entire row)

# %% [markdown]
# Check the data for each country which the entire years of a indicator are missing. We will remove this indicator from the dataframe so that it will not affect the model negatively.

# %%
import operator

# saved indicator
list_deleted_indi = []
list_tuple_country_del_indi = []
for c, i in enumerate(range(0,4480,80)):
    # print(c, df_ccpi['Country Name'][i],df_ccpi[i:i+80].isnull().any(axis=1).sum())
    list_tuple_country_del_indi.append((df_ccpi['Country Name'][i], df_ccpi[i:i+80].isnull().any(axis=1).sum())) 
    for i in df_ccpi[i:i+80]['Indicator Name'][df_ccpi[i:i+80].isnull().any(axis=1)]:
        # print(i)
        list_deleted_indi.append(i)    

# list_tuple_country_del_indi.sort(key=operator.itemgetter(1))
df_tuple_cdi = pd.DataFrame(list_tuple_country_del_indi, columns = ['Country Name','Number of Missing Indicator'])
df_tuple_cdi = df_tuple_cdi.set_index('Country Name')
# df_tuple_cdi.plot(kind = 'bar', figsize=(16,4))

# %%
from bokeh.io import output_notebook
from bokeh.charts import Bar, show

output_notebook()
NA_per_country = Bar(df_tuple_cdi, 'Country Name', values='Number of Missing Indicator', 
        title="Number of Missing Indicator for Each Country",
        plot_width=900, plot_height=450, legend=False)
show(NA_per_country)
# Out:
# C:\Users\N552VX\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="83785d31-676d-4333-b537-639120446116">Loading BokehJS ...</span>
#     </div>
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='0d9ed1d1-b94d-4768-ab90-f66db09fe743', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='0e2db2b3-6c19-44d2-982c-2930ff9e7a74', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='16e8bf7a-2ee7-46eb-8c60-25719274af05', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='2268a70e-0b79-419c-87cc-201ef1f4c8b3', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='288e30c2-a8f4-4dd2-8b23-f34bc89fa23c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='2e351b17-5dab-4578-bb16-86834a57dd52', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='2e856b2a-32d4-4059-94c5-cdd3aab8b93b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='306a7107-04be-4583-9b5e-f263ef2ef351', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='325c22e5-53e8-4563-bede-6341ca9d26c1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='394ee5fd-f88b-44a1-b50c-cd4cbaee2e2e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3b998bbf-b128-43ca-ac66-8fa15fbd773f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3cbf7dd7-d19c-447c-8420-2d2a46e02027', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3ddc9aa0-8fec-4434-8f76-3c16b6d91f4f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='47efc4a3-0922-43c2-b584-5677cf515f75', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='4cbb8998-b375-4e4b-b8a8-a7c762a30643', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='4f702a5b-4274-4802-9858-669ba23924a8', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='54ba7e3a-4a2d-409d-b84a-5f9a561e5f54', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='54fef307-2548-4205-afa2-2a760177ad3a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5640804d-7ff8-4607-8bde-2d68cc03572f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='59efdf9e-7c41-4dbd-a973-3feef1865f46', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5a3c2f7e-73b6-4e01-803e-db72a3d95cf0', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5c795f40-1481-47f1-8da0-828779c6e8e2', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='70d8bcbb-0dfd-4e92-8170-3301ba0458b1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='72eed112-e33a-49ab-a762-c1a5eb2f07d8', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='7bdba4bd-49f8-4b76-acb8-9bcb8d5d898b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='810a59e3-ba33-4bdc-9b00-dbf20f62e299', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='8110cc53-d888-452b-bed5-e8142b85d10d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='830ecf5f-18dc-4667-a7a2-3880e3030023', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='8732e986-d5f6-4291-812d-3ae1bf8e216c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='88343a70-6d78-445e-be3f-e1e45ca57f21', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='8d1d85d2-1e0e-4ff3-8add-0f697bf3379f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='955f1358-3007-4ff4-9f4a-0c38d7b1dfbd', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='9e7e7c9c-fe7e-44bf-991c-87dcd5d3a8ab', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='a05eaca0-d260-45f5-aaa8-701e47ad6c73', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='a0eda5a6-37e3-46c0-af82-2f2e16a699ad', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ab47ebc3-fccd-47b0-b90a-83d72c7c9fee', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='b5b3c636-9144-4b91-9e6e-c8ac1521a246', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='bb8047ea-870d-4d8f-aef5-f6e39629c363', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c27b36fc-b2ac-4295-a01b-985066129965', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c6c6ebf6-215b-49ca-b1e5-f9726ba6d43d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d1895b30-910b-4615-bac9-37591b9be8fa', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d1961f29-59f3-44dc-8041-73167f1a44fb', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d28d21d7-d002-4d7a-ac80-9e99d7274cf9', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d4d8587c-d114-46e8-88e2-2e8a33fdde9e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d7581743-4a7e-4e15-9fa4-1916560fa104', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='daa7349f-87ee-4763-87e0-73fe3e89d0fc', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='dad3bf50-1a1a-47a3-a44d-81488378bdbd', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='dbf922b2-4d6e-4614-b4a1-6acfd3ae8d97', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='dc3eae3c-ab75-4a01-a6e9-0396a92bc2f1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e082e050-4169-41d2-98c6-029529db6f11', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e8a4e5f2-778d-4505-8ce8-8d859d6aac93', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e938a3a0-7555-4803-b957-b859f856147a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ea9e2ae4-ad6e-45e7-b8aa-57549c13f090', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='eb224588-5a9d-4e55-9ce4-985ad6e2a3d0', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='fa12cffe-6e83-4592-b758-fd704aae0182', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='fad050cd-87e1-4f45-ab93-876b1eb00926', ...)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c951fc46-f4a4-494f-bb35-8a22b33f3132"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c951fc46-f4a4-494f-bb35-8a22b33f3132");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c951fc46-f4a4-494f-bb35-8a22b33f3132");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c951fc46-f4a4-494f-bb35-8a22b33f3132' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"418f8aa6-a1bc-4202-8ab3-69801b5c73ac":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ddbf4d2c-8484-4ef5-a2e2-5718ddf528cb","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Russian Federation"],"chart_index":[{"Country Name":"Russian Federation"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":[{"Country Name":"Russian Federation"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Russian Federation"],"y":[2.0]}},"id":"5441dbb2-ed30-4c8d-b844-52f9d8656fd4","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Malta"],"chart_index":[{"Country Name":"Malta"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[8.0],"label":[{"Country Name":"Malta"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Malta"],"y":[4.0]}},"id":"6a7004dc-1253-4169-8b80-0919dd949ed4","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Czech Republic"],"chart_index":[{"Country Name":"Czech Republic"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[10.0],"label":[{"Country Name":"Czech Republic"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Czech Republic"],"y":[5.0]}},"id":"bc0007a9-28f4-4fc6-b7d5-58ed7944d0ad","type":"ColumnDataSource"},{"attributes":{},"id":"4bb30928-5d63-4e9e-a1d1-55de68227fe5","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a14e8481-9de7-44f2-9077-0d9038fed42c","type":"BoxAnnotation"},{"attributes":{},"id":"abc22285-1cda-4bfe-8692-53043a318497","type":"WheelZoomTool"},{"attributes":{"source":null},"id":"2d09b9ae-4a79-4a2c-9754-7b43077525f7","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Iceland"],"chart_index":[{"Country Name":"Iceland"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[8.0],"label":[{"Country Name":"Iceland"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Iceland"],"y":[4.0]}},"id":"25f0d204-3d96-44fc-be99-1d04e8270dfc","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"a14e8481-9de7-44f2-9077-0d9038fed42c","type":"BoxAnnotation"}},"id":"b107068b-2ae6-4e33-8aab-b32f5ceb503a","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Cyprus"],"chart_index":[{"Country Name":"Cyprus"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6.0],"label":[{"Country Name":"Cyprus"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cyprus"],"y":[3.0]}},"id":"46684937-4c6d-434d-8cdd-c0e387863a56","type":"ColumnDataSource"},{"attributes":{},"id":"ec1b87c2-56d5-4046-b7e9-29dd0395e881","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Singapore"],"chart_index":[{"Country Name":"Singapore"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[12.0],"label":[{"Country Name":"Singapore"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Singapore"],"y":[6.0]}},"id":"c9dac62d- ...

# %%
from collections import Counter
deleted_indi_counts = Counter(list_deleted_indi)
df_dic = pd.DataFrame.from_dict(deleted_indi_counts, orient='index')
df_dic.columns = ['Number of Countries']

p = Bar(df_dic, values='Number of Countries', 
        title="Number of Countries which Missing the Indicator",
        plot_width=900, plot_height=700, legend=False)
show(p)
# Out:
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='00033d1d-ddcb-428d-b703-dc1606a18a51', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='0fa31d52-87a8-4884-8ec0-9fa345aeb9f2', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='102c6b0e-e010-4162-8a19-9e1465badab1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='2a0cefb0-048d-4aa5-b1ef-2865477d1591', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3671c365-47e7-4aad-a46a-768102ef8503', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='4035a57b-eb26-41b1-8652-5f8ca6c631f2', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='4d429335-4dd1-4288-a3a9-2f85e72fa51e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5affbcda-a640-466a-960d-33c562fefb9c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5cc3f504-7dad-4024-9c8d-d82f2a024e6a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='6a875473-529e-4427-b82e-16fd483286f1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='8191f73b-b3f0-4f42-a108-aeff8307eb82', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='9c283cb2-033a-4fcd-9614-4026956df0a5', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='9d9c3fbe-2bc2-4385-bb80-e32ed59c5c46', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='a9cea167-a68f-4e00-b7fe-fb8af1a93e2f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='aa68783b-1ae5-465c-8f56-3458419c14d1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ab7c6957-ef1a-4738-a6df-50e11ff29b75', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='b9138d46-c210-415a-b98a-9c5a67e8213e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='de7fd19e-d04d-410c-b3d4-e183081e75af', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e04f5ec8-f85e-44fa-9f96-2efca0d67bb4', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e54fbbf6-3494-4ea9-b13f-0ca0b1351b82', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='f4046ee4-0b99-4532-bd41-c2bceda8e8de', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='f5f23c00-9f01-4dc4-bcc7-506937f7c6de', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='fc51a2d1-8478-4379-ad4a-4408ad9932b9', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='fe4a6f9f-bbfd-4974-8730-d02c387e0c21', ...)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="61c64e88-1b74-493b-b2ac-af78e58da3ca"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("61c64e88-1b74-493b-b2ac-af78e58da3ca");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("61c64e88-1b74-493b-b2ac-af78e58da3ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '61c64e88-1b74-493b-b2ac-af78e58da3ca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"adf158c9-f50c-4a70-8768-7546ede12bb8":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4c58018-4024-40e0-82fa-4f7fe9055323","type":"Rect"},{"attributes":{},"id":"e60d100b-fdde-4cae-9dea-9cf0539a3e99","type":"PanTool"},{"attributes":{},"id":"0f746fa3-57f0-46ce-a4e1-0db0e81c7749","type":"LinearScale"},{"attributes":{"plot":null,"text":"Number of Countries which Missing the Indicator"},"id":"7a592c81-ef46-405d-a56f-dc8654a032a8","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Community health workers (per 1,000 people)"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[47.0],"index":["Community health workers (per 1,000 people)"],"label":[{"index":"Community health workers (per 1,000 people)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Community health workers (per 1,000 people)"],"y":[23.5]}},"id":"36f26c1d-574e-4996-b983-b35a6aa2bed5","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"582af86c-4bb3-4eaa-9fb6-4205e38de485","type":"ColumnDataSource"},"glyph":{"id":"d037adef-1cbb-4067-adef-6abe8cf5cf0b","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"0b699136-edb2-4da2-93b9-46d7dda14d2c","type":"CDSView"}},"id":"b9138d46-c210-415a-b98a-9c5a67e8213e","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8983d1df-e6a5-44ae-9a6c-01d64a679f53","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"82be8087-d7b9-4fae-afe7-9f13e2960f5c","type":"ColumnDataSource"},"glyph":{"id":"2b1c0391-7311-4bdc-a650-5c7fc168a928","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"1e218e71-6f59-4479-83f2-f3100f93277c","type":"CDSView"}},"id":"5affbcda-a640-466a-960d-33c562fefb9c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"748ab532-8fc6-4e4b-a665-3ee768e0659c","type":"ColumnDataSource"},"glyph":{"id":"554b6ec6-0578-42e5-8e8d-5afd9c59c104","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"480c4e3b-3e9d-48e5-aa41-2b8ef70a58c3","type":"CDSView"}},"id":"102c6b0e-e010-4162-8a19-9e1465badab1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Urban land area where elevation is below 5 meters (% of total land area)"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"index":["Urban land area where elevation is below 5 meters (% of total land area)"],"label":[{"index":"Urban land area where elevation is below 5 meters (% of total land area)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Urban land area where elevation is below 5 meters (% of total land area)"],"y":[2.5]}},"id":"582af86c-4bb3-4eaa-9fb6-4205e38de485","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Prevalence of underweight, weight for age (% of children under 5)"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[23.0],"index":["Prevalence of underweight, weight for age (% of children under 5)"],"label":[{"index":"Prevalence of underweight, weight for age (% of children under 5)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Prevalence of underweight, weight for age (% of children under 5)"],"y":[11.5]}},"id":"82be8087-d ...

# %%
# Scatter
#fig = plt.figure()
#ax = fig.add_subplot(1,1,1)
#ax.scatter(df['Age'],df['Sales']) #You can also add more variables here to represent color and size.
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6bb524aee08f> in <module>()
#       2 fig = plt.figure()
#       3 ax = fig.add_subplot(1,1,1)
# ----> 4 ax.scatter(df['Age'],df['Sales']) #You can also add more variables here to represent color and size.
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Filter the data frame so it only consists of the indicators which are complete for the entire year (1960-2016).

# %%
len(set(list_deleted_indi))
# Out:
# 24

# %% [markdown]
# We will have to remove 24 indicators from the data. It leaves us with the remaining 56 indicators.

# %%
df_ccpi_clean = pd.DataFrame()

# initialize the flag of saved indicator
array_flag = np.ones((len(df_ccpi)), dtype=bool)

# transfom it to series
series_flag = pd.Series(data = array_flag, index=range(len(df_ccpi)))

# filter the indicator
for indi in sorted(set(list_deleted_indi)):
    series_flag = (series_flag & (df_ccpi['Indicator Name'] != indi))

# filter the df
df_ccpi_clean_reset = df_ccpi[series_flag]

print('Number of row with missing value:', df_ccpi_clean_reset.isnull().any().sum())
# Out:
# Number of row with missing value: 0

# %% [markdown]
# As we could see from dataframe calculation above, we do not have missing value anymore.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Averaging and Summing the Features

# %% [markdown]
# We already have done preprocessing to our data, but to make it even more meaningful as the input features for the model we need to 'engineer' the data. We will sum up or re-average the data as the appropriate interaction to do based on the source note on the countries metadata. We might even remove the data if the data is considered as redundant or are already represented by another feature. The information of the metadata is concluded as the csv file below.

# %%
df_feature_select = pd.read_csv('world_bank/feature_engineering.csv',sep=',', header=0)

# %%
df_feature_select.head()
# Out:
#                        Indicator Name Feature Interaction
# 0       Urban population (% of total)              remove
# 1                    Urban population                 sum
# 2  Urban population growth (annual %)             average
# 3                   Population, total                 sum
# 4        Population growth (annual %)             average

# %%
df_ccpi_feature_label = pd.merge(df_ccpi_clean_reset, df_feature_select, 
                                 on = 'Indicator Name', how="inner")

print('Dataframe shape:', df_ccpi_feature_label.shape)
df_ccpi_feature_label.head()
# Out:
# Dataframe shape: (2907, 62)
#      Country Name Country Code                 Indicator Name  \
# 0          France          FRA  Urban population (% of total)
# 1          Sweden          SWE  Urban population (% of total)
# 2  United Kingdom          GBR  Urban population (% of total)
# 3          Cyprus          CYP  Urban population (% of total)
# 4         Morocco          MAR  Urban population (% of total)
#
#       Indicator Code    1960    1961    1962    1963    1964    1965  \
# 0  SP.URB.TOTL.IN.ZS  61.880  62.607  63.489  64.702  65.898  67.071
# 1  SP.URB.TOTL.IN.ZS  72.490  73.295  74.271  75.223  76.153  77.056
# 2  SP.URB.TOTL.IN.ZS  78.444  78.374  78.237  78.099  77.960  77.821
# 3  SP.URB.TOTL.IN.ZS  35.628  36.175  36.674  37.176  37.681  38.188
# 4  SP.URB.TOTL.IN.ZS  29.357  29.849  30.345  30.846  31.353  31.862
#
#           ...             2008    2009    2010    2011    2012    2013  \
# 0         ...           77.864  78.106  78.345  78.584  78.820  79.055
# 1         ...           84.746  84.902  85.056  85.210  85.363  85.514
# 2         ...           80.757  81.031  81.302  81.570  81.834  82.092
# 3         ...           67.839  67.695  67.551  67.406  67.261  67.133
# 4         ...           56.665  57.175  57.684  58.191  58.697  59.200
#
#      2014    2015    2016  Feature Interaction
# 0  79.289  79.520  79.750               remove
# 1  85.665  85.815  85.964               remove
# 2  82.345  82.592  82.835               remove
# 3  67.019  66.921  66.840               remove
# 4  59.699  60.195  60.685               remove
#
# [5 rows x 62 columns]

# %%
df_ccpi_feature_label_removed = df_ccpi_feature_label [df_ccpi_feature_label['Feature Interaction'] != 'remove']
print('Dataframe shape:', df_ccpi_feature_label_removed.shape)
df_ccpi_feature_label_removed.head()
# Out:
# Dataframe shape: (2451, 62)
#       Country Name Country Code    Indicator Name Indicator Code        1960  \
# 57          France          FRA  Urban population    SP.URB.TOTL  28968650.0
# 58          Sweden          SWE  Urban population    SP.URB.TOTL   5425627.0
# 59  United Kingdom          GBR  Urban population    SP.URB.TOTL  41104656.0
# 60          Cyprus          CYP  Urban population    SP.URB.TOTL    204124.0
# 61         Morocco          MAR  Urban population    SP.URB.TOTL   3619287.0
#
#           1961        1962        1963        1964        1965  \
# 57  29703735.0  30550684.0  31576957.0  32586168.0  33551445.0
# 58   5511783.0   5616067.0   5720204.0   5834351.0   5959398.0
# 59  41381472.0  41661202.0  41900114.0  42098400.0  42294196.0
# 60    208511.0    211862.0    214845.0    218032.0    221859.0
# 61   3793971.0   3973623.0   4157495.0   4344630.0   4533658.0
#
#            ...                 2008        2009        2010        2011  \
# 57         ...           50124942.0  50540084.0  50945804.0  51348967.0
# 58         ...            7813274.0   7894625.0   7976659.0   8051674.0
# 59         ...           49913475.0  50463084.0  51030310.0  51600299.0
# 60         ...             733722.0    743343.0    751577.0    758206.0
# 61         ...           17904358.0  18290224.0  18695176.0  19120878.0
#
#           2012        2013        2014        2015        2016  \
# 57  51753046.0  52175170.0  52593945.0  52979459.0  53349647.0
# 58   8126023.0   8209668.0   8306173.0   8409171.0   8513120.0
# 59  52128504.0  52644143.0  53205707.0  53791229.0  54370607.0
# 60    763454.0    767932.0    772266.0    776943.0    782112.0
# 61  19565934.0  20024263.0  20487552.0  20949860.0  21407718.0
#
#     Feature Interaction
# 57                  sum
# 58                  sum
# 59                  sum
# 60                  sum
# 61                  sum
#
# [5 rows x 62 columns]

# %% [markdown]
# The number of features to be summed.

# %%
set_indi_sum = set(df_ccpi_feature_label_removed[df_ccpi_feature_label_removed['Feature Interaction'] == 'sum']['Indicator Name'])
len(set_indi_sum)
# Out:
# 14

# %% [markdown]
# The number of features to be averaged.

# %%
set_indi_average = set(df_ccpi_feature_label_removed[df_ccpi_feature_label_removed['Feature Interaction'] == 'average']['Indicator Name'])
len(set_indi_average)
# Out:
# 29

# %% [markdown]
# Generate new engineered dataframe. First we append the dataframe with the averaged features.

# %%
df_ccpi_feature_processed = pd.DataFrame()

for indi in set_indi_average:
    df_indi = df_ccpi_feature_label_removed[(df_ccpi_feature_label_removed['Feature Interaction'] == 'average') & (df_ccpi_feature_label_removed['Indicator Name'] == indi)]
    df_indi_ave = (df_indi.sum(axis = 0)) 
    
    df_ccpi_feature_processed[indi] = df_indi_ave[4:-1]/len(ccpi_country)
    
print('Dataframe shape:',df_ccpi_feature_processed.shape)    
df_ccpi_feature_processed.head()
# Out:
# Dataframe shape: (57, 29)
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.46768
# 1961                                  0.46768
# 1962                                  0.46768
# 1963                                  0.46768
# 1964                                  0.46768
#
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                            78.6085
# 1961                                            78.6085
# 1962                                            78.6085
# 1963                                            78.6085
# 1964                                            78.6085
#
#      Population growth (annual %)  \
# 1960                      1.73957
# 1961                      1.54375
# 1962                      1.53823
# 1963                       1.5221
# 1964                      1.50488
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.42281
# 1961                                          4.42281
# 1962                                          4.42281
# 1963                                          4.42281
# 1964                                          4.42281
#
#      Access to electricity (% of population)  \
# 1960                                 94.5262
# 1961                                 94.5262
# 1962                                 94.5262
# 1963                                 94.5262
# 1964                                 94.5262
#
#      Energy use (kg of oil equivalent per capita)  \
# 1960                                      2131.99
# 1961                                      2147.36
# 1962                                      2189.16
# 1963                                      2246.68
# 1964                                      2294.52
#
#      CO2 emissions (metric tons per capita)  \
# 1960                                5.56605
# 1961                                5.60803
# 1962                                5.75007
# 1963                                5.92478
# 1964                                6.12698
#
#      Average precipitation in depth (mm per year)  \
# 1960                                      928.316
# 1961                                      928.316
# 1962                                      928.316
# 1963                                      928.316
# 1964                                      928.316
#
#      Electricity production from hydroelectric sources (% of total)  \
# 1960                                            33.5841
# 1961                                            33.4155
# 1962                                            32.6826
# 1963                                            32.8665
# 1964                                            31.7092
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                            180.797
# 1961                                            180.797
# 1962                                            180.797
# 1963                                            180.797
# 1964                                            180.797
#
#                                  ...                               \
# 1960                             ...
# 1961                             ...
# 1962                             ...
# 1963                             ...
# 1964                             ...
#
#      Electricity production from natural gas sources (% of total)  \
# 1960                                            6.90008
# 1961                                            6.94622
# 1962                                            6.96586
# 1963                                            6.95194
# 1964                                            6.92347
#
#      Urban population growth (annual %)  \
# 1960                            3.12379
# 1961                            2.97242
# 1962                            3.00569
# 1963                            2.99205
# 1964                            2.96685
#
#      Terrestrial and marine protected areas (% of total territorial area)  \
# 1960                                            5.06895
# 1961                                            5.06895
# 1962                                            5.06895
# 1963                                            5.06895
# 1964                                            5.06895
#
#      Arable land (% of land area)  \
# 1960                      22.9618
# 1961                      22.9618
# 1962                      22.8923
# 1963                      22.8414
# 1964                      22.7635
#
#      Terrestrial protected areas (% of total land area)  \
# 1960                                            7.67368
# 1961                                            7.67368
# 1962                                            7.67368
# 1963                                            7.67368
# 1964                                            7.67368
#
#      Nitrous oxide emissions (% change from 1990)  \
# 1960                                     -1.81816
# 1961                                     -1.81816
# 1962                                     -1.81816
# 1963                                     -1.81816
# 1964                                     -1.81816
#
#      Electric power consumption (kWh per capita)  \
# 1960                                     2061.68
# 1961                                     2120.47
# 1962                                     2191.57
# 1963                                     2278.87
# 1964                                     2389.13
#
#      Methane emissions (% change from 1990)  \
# 1960                                1.33255
# 1961                                1.33255
# 1962                                1.33255
# 1963                                1.33255
# 1964                                1.33255
#
#      Improved water source (% of population with access)  \
# 1960                                            94.1754
# 1961                                            94.1754
# 1962                                            94.1754
# 1963                                            94.1754
# 1964                                            94.1754
#
#      Renewable electricity output (% of total electricity output)
# 1960                                            21.6549
# 1961                                            21.6549
# 1962                                            21.6549
# 1963                                            21.6549
# 1964                                            21.6549
#
# [5 rows x 29 columns]

# %% [markdown]
# Calculate and append the summed features.

# %%
for indi in set_indi_sum:
    df_indi = df_ccpi_feature_label_removed[(df_ccpi_feature_label_removed['Feature Interaction'] == 'sum') & (df_ccpi_feature_label_removed['Indicator Name'] == indi)]
    df_indi_sum = df_indi.sum(axis = 0)
    
    df_ccpi_feature_processed[indi] = df_indi_sum[4:-1]
    
print('Dataframe shape:',df_ccpi_feature_processed.shape)    
df_ccpi_feature_processed.head()
# Out:
# Dataframe shape: (57, 43)
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.46768
# 1961                                  0.46768
# 1962                                  0.46768
# 1963                                  0.46768
# 1964                                  0.46768
#
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                            78.6085
# 1961                                            78.6085
# 1962                                            78.6085
# 1963                                            78.6085
# 1964                                            78.6085
#
#      Population growth (annual %)  \
# 1960                      1.73957
# 1961                      1.54375
# 1962                      1.53823
# 1963                       1.5221
# 1964                      1.50488
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.42281
# 1961                                          4.42281
# 1962                                          4.42281
# 1963                                          4.42281
# 1964                                          4.42281
#
#      Access to electricity (% of population)  \
# 1960                                 94.5262
# 1961                                 94.5262
# 1962                                 94.5262
# 1963                                 94.5262
# 1964                                 94.5262
#
#      Energy use (kg of oil equivalent per capita)  \
# 1960                                      2131.99
# 1961                                      2147.36
# 1962                                      2189.16
# 1963                                      2246.68
# 1964                                      2294.52
#
#      CO2 emissions (metric tons per capita)  \
# 1960                                5.56605
# 1961                                5.60803
# 1962                                5.75007
# 1963                                5.92478
# 1964                                6.12698
#
#      Average precipitation in depth (mm per year)  \
# 1960                                      928.316
# 1961                                      928.316
# 1962                                      928.316
# 1963                                      928.316
# 1964                                      928.316
#
#      Electricity production from hydroelectric sources (% of total)  \
# 1960                                            33.5841
# 1961                                            33.4155
# 1962                                            32.6826
# 1963                                            32.8665
# 1964                                            31.7092
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                            180.797
# 1961                                            180.797
# 1962                                            180.797
# 1963                                            180.797
# 1964                                            180.797
#
#                        ...                     \
# 1960                   ...
# 1961                   ...
# 1962                   ...
# 1963                   ...
# 1964                   ...
#
#      Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.59646e+06
# 1961                                        1.59646e+06
# 1962                                        1.59646e+06
# 1963                                        1.59646e+06
# 1964                                        1.59646e+06
#
#      Total greenhouse gas emissions (kt of CO2 equivalent)  \
# 1960                                        2.15698e+07
# 1961                                        2.15698e+07
# 1962                                        2.15698e+07
# 1963                                        2.15698e+07
# 1964                                        2.15698e+07
#
#      Electricity production from renewable sources, excluding hydroelectric (kWh)  \
# 1960                                          3.791e+09
# 1961                                          4.179e+09
# 1962                                          4.548e+09
# 1963                                          5.113e+09
# 1964                                          5.404e+09
#
#      Agricultural land (sq. km)  \
# 1960                3.04398e+07
# 1961                3.04398e+07
# 1962                3.04956e+07
# 1963                 3.0559e+07
# 1964                 3.0608e+07
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                             104428
# 1961                                             104428
# 1962                                             104428
# 1963                                             104428
# 1964                                             104428
#
#      Urban population Population, total  \
# 1960      8.82316e+08       2.42165e+09
# 1961       9.0571e+08       2.44721e+09
# 1962      9.31088e+08       2.48411e+09
# 1963      9.59149e+08       2.53265e+09
# 1964       9.8775e+08       2.58106e+09
#
#      Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.71553e+06
# 1961                                        1.71553e+06
# 1962                                        1.71553e+06
# 1963                                        1.71553e+06
# 1964                                        1.71553e+06
#
#      CO2 emissions (kt) Methane emissions (kt of CO2 equivalent)
# 1960        1.06706e+07                               4.0302e+06
# 1961        1.05782e+07                               4.0302e+06
# 1962         1.0736e+07                               4.0302e+06
# 1963        1.10676e+07                               4.0302e+06
# 1964         1.1395e+07                               4.0302e+06
#
# [5 rows x 43 columns]

# %% [markdown]
# # Training Set

# %% [markdown]
# In this step, input feature matrix and target vector are established from previously loaded data to train the model of Linear Regression.

# %% [markdown]
# ## Feature Matrix

# %% [markdown]
# Input matrix is obtained from world bank data, with rows as year from 1960 to 2016 and columns as indicators for each countries.

# %%
X_tempe_train = df_ccpi_feature_processed

dataset_tempe = X_tempe_train[X_tempe_train.columns.values]

print('Dataframe shape:', dataset_tempe.shape)
dataset_tempe.head()
# Out:
# Dataframe shape: (57, 43)
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.46768
# 1961                                  0.46768
# 1962                                  0.46768
# 1963                                  0.46768
# 1964                                  0.46768
#
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                            78.6085
# 1961                                            78.6085
# 1962                                            78.6085
# 1963                                            78.6085
# 1964                                            78.6085
#
#      Population growth (annual %)  \
# 1960                      1.73957
# 1961                      1.54375
# 1962                      1.53823
# 1963                       1.5221
# 1964                      1.50488
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.42281
# 1961                                          4.42281
# 1962                                          4.42281
# 1963                                          4.42281
# 1964                                          4.42281
#
#      Access to electricity (% of population)  \
# 1960                                 94.5262
# 1961                                 94.5262
# 1962                                 94.5262
# 1963                                 94.5262
# 1964                                 94.5262
#
#      Energy use (kg of oil equivalent per capita)  \
# 1960                                      2131.99
# 1961                                      2147.36
# 1962                                      2189.16
# 1963                                      2246.68
# 1964                                      2294.52
#
#      CO2 emissions (metric tons per capita)  \
# 1960                                5.56605
# 1961                                5.60803
# 1962                                5.75007
# 1963                                5.92478
# 1964                                6.12698
#
#      Average precipitation in depth (mm per year)  \
# 1960                                      928.316
# 1961                                      928.316
# 1962                                      928.316
# 1963                                      928.316
# 1964                                      928.316
#
#      Electricity production from hydroelectric sources (% of total)  \
# 1960                                            33.5841
# 1961                                            33.4155
# 1962                                            32.6826
# 1963                                            32.8665
# 1964                                            31.7092
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                            180.797
# 1961                                            180.797
# 1962                                            180.797
# 1963                                            180.797
# 1964                                            180.797
#
#                        ...                     \
# 1960                   ...
# 1961                   ...
# 1962                   ...
# 1963                   ...
# 1964                   ...
#
#      Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.59646e+06
# 1961                                        1.59646e+06
# 1962                                        1.59646e+06
# 1963                                        1.59646e+06
# 1964                                        1.59646e+06
#
#      Total greenhouse gas emissions (kt of CO2 equivalent)  \
# 1960                                        2.15698e+07
# 1961                                        2.15698e+07
# 1962                                        2.15698e+07
# 1963                                        2.15698e+07
# 1964                                        2.15698e+07
#
#      Electricity production from renewable sources, excluding hydroelectric (kWh)  \
# 1960                                          3.791e+09
# 1961                                          4.179e+09
# 1962                                          4.548e+09
# 1963                                          5.113e+09
# 1964                                          5.404e+09
#
#      Agricultural land (sq. km)  \
# 1960                3.04398e+07
# 1961                3.04398e+07
# 1962                3.04956e+07
# 1963                 3.0559e+07
# 1964                 3.0608e+07
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                             104428
# 1961                                             104428
# 1962                                             104428
# 1963                                             104428
# 1964                                             104428
#
#      Urban population Population, total  \
# 1960      8.82316e+08       2.42165e+09
# 1961       9.0571e+08       2.44721e+09
# 1962      9.31088e+08       2.48411e+09
# 1963      9.59149e+08       2.53265e+09
# 1964       9.8775e+08       2.58106e+09
#
#      Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.71553e+06
# 1961                                        1.71553e+06
# 1962                                        1.71553e+06
# 1963                                        1.71553e+06
# 1964                                        1.71553e+06
#
#      CO2 emissions (kt) Methane emissions (kt of CO2 equivalent)
# 1960        1.06706e+07                               4.0302e+06
# 1961        1.05782e+07                               4.0302e+06
# 1962         1.0736e+07                               4.0302e+06
# 1963        1.10676e+07                               4.0302e+06
# 1964         1.1395e+07                               4.0302e+06
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Target Vector

# %% [markdown]
# Target vector is global temperature anomaly from 1960 to 2016.

# %%
y_tempe_train = df_tempe_since_1960['annual mean'].values
# y_tempe_train = df_tempe_since_1960['5 year mean'].values
print('Dataframe shape:', y_tempe_train.shape)
y_tempe_train
# Out:
# Dataframe shape: (57,)
# array([-0.02,  0.05,  0.03,  0.06, -0.2 , -0.1 , -0.05, -0.02, -0.07,
#         0.07,  0.02, -0.09,  0.01,  0.15, -0.07, -0.02, -0.11,  0.18,
#         0.07,  0.17,  0.27,  0.33,  0.13,  0.3 ,  0.15,  0.12,  0.19,
#         0.33,  0.41,  0.28,  0.44,  0.43,  0.23,  0.24,  0.32,  0.46,
#         0.35,  0.48,  0.64,  0.42,  0.42,  0.55,  0.63,  0.62,  0.55,
#         0.69,  0.63,  0.66,  0.54,  0.64,  0.71,  0.6 ,  0.63,  0.65,
#         0.74,  0.87,  0.99])

# %% [markdown]
# ### Concat the target to the main matrix

# %%
dataset_tempe['target'] = y_tempe_train
print('Dataframe shape:', dataset_tempe.shape)
dataset_tempe.head()
# Out:
# Dataframe shape: (57, 44)
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.46768
# 1961                                  0.46768
# 1962                                  0.46768
# 1963                                  0.46768
# 1964                                  0.46768
#
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                            78.6085
# 1961                                            78.6085
# 1962                                            78.6085
# 1963                                            78.6085
# 1964                                            78.6085
#
#      Population growth (annual %)  \
# 1960                      1.73957
# 1961                      1.54375
# 1962                      1.53823
# 1963                       1.5221
# 1964                      1.50488
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.42281
# 1961                                          4.42281
# 1962                                          4.42281
# 1963                                          4.42281
# 1964                                          4.42281
#
#      Access to electricity (% of population)  \
# 1960                                 94.5262
# 1961                                 94.5262
# 1962                                 94.5262
# 1963                                 94.5262
# 1964                                 94.5262
#
#      Energy use (kg of oil equivalent per capita)  \
# 1960                                      2131.99
# 1961                                      2147.36
# 1962                                      2189.16
# 1963                                      2246.68
# 1964                                      2294.52
#
#      CO2 emissions (metric tons per capita)  \
# 1960                                5.56605
# 1961                                5.60803
# 1962                                5.75007
# 1963                                5.92478
# 1964                                6.12698
#
#      Average precipitation in depth (mm per year)  \
# 1960                                      928.316
# 1961                                      928.316
# 1962                                      928.316
# 1963                                      928.316
# 1964                                      928.316
#
#      Electricity production from hydroelectric sources (% of total)  \
# 1960                                            33.5841
# 1961                                            33.4155
# 1962                                            32.6826
# 1963                                            32.8665
# 1964                                            31.7092
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                            180.797
# 1961                                            180.797
# 1962                                            180.797
# 1963                                            180.797
# 1964                                            180.797
#
#       ...   Total greenhouse gas emissions (kt of CO2 equivalent)  \
# 1960  ...                                          2.15698e+07
# 1961  ...                                          2.15698e+07
# 1962  ...                                          2.15698e+07
# 1963  ...                                          2.15698e+07
# 1964  ...                                          2.15698e+07
#
#      Electricity production from renewable sources, excluding hydroelectric (kWh)  \
# 1960                                          3.791e+09
# 1961                                          4.179e+09
# 1962                                          4.548e+09
# 1963                                          5.113e+09
# 1964                                          5.404e+09
#
#      Agricultural land (sq. km)  \
# 1960                3.04398e+07
# 1961                3.04398e+07
# 1962                3.04956e+07
# 1963                 3.0559e+07
# 1964                 3.0608e+07
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                             104428
# 1961                                             104428
# 1962                                             104428
# 1963                                             104428
# 1964                                             104428
#
#      Urban population Population, total  \
# 1960      8.82316e+08       2.42165e+09
# 1961       9.0571e+08       2.44721e+09
# 1962      9.31088e+08       2.48411e+09
# 1963      9.59149e+08       2.53265e+09
# 1964       9.8775e+08       2.58106e+09
#
#      Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.71553e+06
# 1961                                        1.71553e+06
# 1962                                        1.71553e+06
# 1963                                        1.71553e+06
# 1964                                        1.71553e+06
#
#      CO2 emissions (kt) Methane emissions (kt of CO2 equivalent) target
# 1960        1.06706e+07                               4.0302e+06  -0.02
# 1961        1.05782e+07                               4.0302e+06   0.05
# 1962         1.0736e+07                               4.0302e+06   0.03
# 1963        1.10676e+07                               4.0302e+06   0.06
# 1964         1.1395e+07                               4.0302e+06  -0.20
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Generating the Model

# %%
from sklearn.linear_model import LinearRegression
lr_tempe = LinearRegression(fit_intercept=True)
lr_tempe.fit(X_tempe_train, y_tempe_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.ensemble import RandomForestRegressor

max_depth = 30
regr_rf = RandomForestRegressor(max_depth=max_depth, random_state=2)
regr_rf.fit(X_tempe_train, y_tempe_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=30,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=2, verbose=0, warm_start=False)

# %%
from sklearn.svm import SVR

svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_rbf.fit(X_tempe_train, y_tempe_train)
# Out:
# SVR(C=1000.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Predict the anomaly temperature

# %%
dataset_tempe['LR prediction'] = lr_tempe.predict(X_tempe_train)
dataset_tempe['RFR prediction'] = regr_rf.predict(X_tempe_train)
dataset_tempe['SVR prediction'] = svr_rbf.predict(X_tempe_train)
print('Dataframe shape:', dataset_tempe.shape)
dataset_tempe.head()
# Out:
# Dataframe shape: (57, 47)
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.46768
# 1961                                  0.46768
# 1962                                  0.46768
# 1963                                  0.46768
# 1964                                  0.46768
#
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                            78.6085
# 1961                                            78.6085
# 1962                                            78.6085
# 1963                                            78.6085
# 1964                                            78.6085
#
#      Population growth (annual %)  \
# 1960                      1.73957
# 1961                      1.54375
# 1962                      1.53823
# 1963                       1.5221
# 1964                      1.50488
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.42281
# 1961                                          4.42281
# 1962                                          4.42281
# 1963                                          4.42281
# 1964                                          4.42281
#
#      Access to electricity (% of population)  \
# 1960                                 94.5262
# 1961                                 94.5262
# 1962                                 94.5262
# 1963                                 94.5262
# 1964                                 94.5262
#
#      Energy use (kg of oil equivalent per capita)  \
# 1960                                      2131.99
# 1961                                      2147.36
# 1962                                      2189.16
# 1963                                      2246.68
# 1964                                      2294.52
#
#      CO2 emissions (metric tons per capita)  \
# 1960                                5.56605
# 1961                                5.60803
# 1962                                5.75007
# 1963                                5.92478
# 1964                                6.12698
#
#      Average precipitation in depth (mm per year)  \
# 1960                                      928.316
# 1961                                      928.316
# 1962                                      928.316
# 1963                                      928.316
# 1964                                      928.316
#
#      Electricity production from hydroelectric sources (% of total)  \
# 1960                                            33.5841
# 1961                                            33.4155
# 1962                                            32.6826
# 1963                                            32.8665
# 1964                                            31.7092
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                            180.797
# 1961                                            180.797
# 1962                                            180.797
# 1963                                            180.797
# 1964                                            180.797
#
#           ...        \
# 1960      ...
# 1961      ...
# 1962      ...
# 1963      ...
# 1964      ...
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                             104428
# 1961                                             104428
# 1962                                             104428
# 1963                                             104428
# 1964                                             104428
#
#      Urban population Population, total  \
# 1960      8.82316e+08       2.42165e+09
# 1961       9.0571e+08       2.44721e+09
# 1962      9.31088e+08       2.48411e+09
# 1963      9.59149e+08       2.53265e+09
# 1964       9.8775e+08       2.58106e+09
#
#      Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.71553e+06
# 1961                                        1.71553e+06
# 1962                                        1.71553e+06
# 1963                                        1.71553e+06
# 1964                                        1.71553e+06
#
#      CO2 emissions (kt) Methane emissions (kt of CO2 equivalent) target  \
# 1960        1.06706e+07                               4.0302e+06  -0.02
# 1961        1.05782e+07                               4.0302e+06   0.05
# 1962         1.0736e+07                               4.0302e+06   0.03
# 1963        1.10676e+07                               4.0302e+06   0.06
# 1964         1.1395e+07                               4.0302e+06  -0.20
#
#      LR prediction RFR prediction SVR prediction
# 1960      0.034331         -0.011       0.079867
# 1961      0.088720          0.024       0.149867
# 1962     -0.009342          0.035       0.129867
# 1963      0.132098          0.057       0.159867
# 1964     -0.184557         -0.119      -0.100133
#
# [5 rows x 47 columns]

# %%
dataset_tempe[['target', 'LR prediction', 'RFR prediction', 'SVR prediction']].plot(figsize = (16,5), alpha=0.6);

# %% [markdown]
# ## Analysis

# %%
# Recursive Feature Elimination
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

target_int = (dataset_tempe.target*100).astype(int)

# create a base classifier used to evaluate a subset of attributes
RFEmodel = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(RFEmodel, 7)
rfe = rfe.fit(X_tempe_train, target_int) #dataset_tempe.target)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False  True  True  True False
#   True False False False  True  True  True]
# [37 16 34 29 19  9 32 11 20 13 25 33 35 21 36 22 15 26 17 27 31 30 24 28 12
#   8 14 18 23 10  6  5  1  1  1  4  1  7  2  3  1  1  1]

# %%
X_tempe_train.columns[rfe.support_]
# Out:
# Index(['Forest area (sq. km)',
#        'Nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#        'Total greenhouse gas emissions (kt of CO2 equivalent)',
#        'Agricultural land (sq. km)',
#        'Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#        'CO2 emissions (kt)', 'Methane emissions (kt of CO2 equivalent)'],
#       dtype='object')

# %%
f, axarr = plt.subplots(7, sharex=True)

for i, indi in enumerate(X_tempe_train.columns[rfe.support_]):
    # print(indi)
    axarr[i].plot(dataset_tempe[indi].index, dataset_tempe[indi].values)

# %%
from bokeh.io import gridplot, show
from bokeh.plotting import figure

plotList = []
colorList = ["olive", "navy", "coral", "greenyellow", "dodgerblue", "darkmagenta", "firebrick"]
for i in range(0,len(X_tempe_train.columns[rfe.support_])):
    labelName = X_tempe_train.columns[rfe.support_][i].split("(")
    yAxisName = labelName[1].replace(")","").replace(" of CO2 equivalent","")
    s = figure(width=400, height=250, title=labelName[0],x_axis_label="years",y_axis_label=yAxisName+" * 10^6")
    s.line(dataset_tempe[X_tempe_train.columns[rfe.support_][i]].index, dataset_tempe[X_tempe_train.columns[rfe.support_][i]].values/10**6, line_width=5, color=colorList[i], alpha=0.5)
    plotList.append(s)
    
p = gridplot([[plotList[0], plotList[1], plotList[2]], [plotList[3], plotList[4], plotList[5]],[plotList[6],None,None]])

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="77dc9d91-f9c2-42ab-b8a4-cea6804c7f0f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("77dc9d91-f9c2-42ab-b8a4-cea6804c7f0f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("77dc9d91-f9c2-42ab-b8a4-cea6804c7f0f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '77dc9d91-f9c2-42ab-b8a4-cea6804c7f0f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d67cebfb-c86b-4e05-8396-c29d5e03094e":{"roots":{"references":[{"attributes":{},"id":"4a10d24f-b87a-4c61-8904-07730a77c217","type":"WheelZoomTool"},{"attributes":{},"id":"9f7f2eff-4eef-4ccc-bb56-5224242f4dee","type":"SaveTool"},{"attributes":{"below":[{"id":"b63949f4-6189-4611-b8b2-ab41c6dc4760","type":"LinearAxis"}],"left":[{"id":"7fb64956-e615-41b4-baa6-d48f981aa27e","type":"LinearAxis"}],"plot_height":250,"plot_width":400,"renderers":[{"id":"b63949f4-6189-4611-b8b2-ab41c6dc4760","type":"LinearAxis"},{"id":"761b61b3-9d26-424b-ab33-c55093cc8104","type":"Grid"},{"id":"7fb64956-e615-41b4-baa6-d48f981aa27e","type":"LinearAxis"},{"id":"e9166a01-6fb6-4be5-a679-0f71213015c5","type":"Grid"},{"id":"352a820e-218c-4e8a-ac01-47c2382c19e3","type":"BoxAnnotation"},{"id":"ab794c41-dfd4-43e3-91c7-18b15a8fd923","type":"GlyphRenderer"}],"title":{"id":"23e0f8fa-578b-4b09-b116-c0918fb79239","type":"Title"},"toolbar":{"id":"6f4cce70-ff27-45fa-88bc-7bd4402fb953","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"9fd06869-1a65-4672-9386-0010f03b73c3","type":"DataRange1d"},"x_scale":{"id":"6169716c-9ea9-4460-94b3-69d741469e99","type":"LinearScale"},"y_range":{"id":"ee2449e6-dc90-443d-ba68-eefa8ed0f5ac","type":"DataRange1d"},"y_scale":{"id":"222e7fee-7ab0-4e52-bc0c-1759c8333f43","type":"LinearScale"}},"id":"16bde325-644b-425c-905f-52e8b196a612","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"sq. km * 10^6","formatter":{"id":"16b4618d-9f02-4f1f-943d-7179b770a95c","type":"BasicTickFormatter"},"plot":{"id":"22e20f5e-9387-45e2-bdec-1b1faad3cc6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"28f0e729-6bb4-4b7d-936d-9c8d01b2c6bf","type":"BasicTicker"}},"id":"4817ad82-88d2-4c2e-9815-58902829817c","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8af87661-3ecf-409c-9610-a64e5aefe7d1","type":"BoxAnnotation"},{"attributes":{},"id":"d79f9911-6631-427e-9360-fb7be0ba27d3","type":"BasicTicker"},{"attributes":{},"id":"eb44fe5f-067e-431d-a50a-769840764e4e","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"3c140a07-72ef-468c-a9a9-9d7950893713","subtype":"Figure","type":"Plot"},"ticker":{"id":"d79f9911-6631-427e-9360-fb7be0ba27d3","type":"BasicTicker"}},"id":"04b2789a-5b4a-45f6-9d90-70dbb2f11fc7","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"d6165697-7dd6-44ff-80e0-f15c96719d01","type":"Line"},{"attributes":{},"id":"d64a249e-2f7d-4996-9f99-3634c1a7e8ed","type":"HelpTool"},{"attributes":{"data_source":{"id":"eeb94c27-972f-4de2-854b-3560e07b90a7","type":"ColumnDataSource"},"glyph":{"id":"dd6d2eda-8bd8-4be7-aea6-ff9eda466cd5","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3313da11-0431-431b-99c4-001057812720","type":"Line"},"selection_glyph":null,"view":{"id":"c7776f30-d86b-4b55-aaba-521b51d93580","type":"CDSView"}},"id":"73beb80f-1bed-466c-90f8-50d4a1609bdf","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"16bde325-644b-425c-905f-52e8b196a612","subtype":"Figure","type":"Plot"},{"id":"6c3eb7d4-7efe-40d4-bb6b-b616426e450d","type":"Spacer"},{"id":"efe2d224-e7fc-400d-830d-4c90ba59787e","type":"Spacer"}]},"id":"0fb903f0-1944-4b10-9c75-1feff22559ac","type":"Row"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ba2cc2c5-041e-4312-8db7-4df0fc3ae0bb","type":"BoxAnnotation"},{"attributes":{"source ...

# %% [markdown]
# Nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# Methane emissions (kt of CO2 equivalent)
# Forest area (sq. km)
# Agricultural land (sq. km)
# Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)
# Total greenhouse gas emissions (kt of CO2 equivalent)
# CO2 emissions (kt)

# %% [markdown]
# # Prediction on the Future Condition

# %% [markdown]
# ## Global temperature anomaly in the near future

# %%
y_tempe_train = df_tempe_since_1960['5 year mean'].values
dataset_tempe['5 year'] = y_tempe_train
regr_rf.fit(X_tempe_train, y_tempe_train)

# %%
dataset_tempe['RFR future prediction'] = regr_rf.predict(X_tempe_train)

# %%
dataset_tempe[['5 year','RFR future prediction']].plot(figsize = (16,5), alpha=0.6);

# %% [markdown]
# After doing Recrusive Feature Elimination on our dataset, indicators which has most significant contribution to global temperature anomaly can be discovered. We found top seven indicators, which are:
#
# * **Nitrous oxide emissions (thousand metric tons of CO<sub>2</sub> equivalent)**
# <dd> While it contributes only 5 percent of US greenhouse gas emission in 2015. But according to EPA, the impact of 1 pound of N<sub>2</sub>O on warming the atmosphere is almost 300 times that of 1 pound of carbon dioxide [1]. </dd>
#
#
# * **Methane emissions (kt of CO<sub>2</sub> equivalent)**
# <dd> Pound for pound, the comparative impact of CH<sub>4</sub> is more than 25 times greater than CO<sub>2</sub> over a 100-year period [1]. Though it only contributes only 10 percent of US greenhouse gas emission in 2015.</dd>
#
#
# * **Forest area (sq. km)**
# <dd> As described by plot of Forest Area above, the trend of forest area in the world since 1990 is decreasing, though slowly it increases since 2000. It means that deforestation keeps happening around the world. In accordance with World Carfree Network (WCN) [3], deforestation contributes to 15 percent of global carbon dioxide emissions</dd>
#
#
# * **Agricultural land (sq. km)**
# <dd> Agriculture actually contributes to climate change. At every stage of agricultural process, some greenhouse gases are released into atmosphere. For example, Nitrous Oxide is emitted when people use synthetic fertilizers to the soil or domestic livestock such as cattle also produce a large amount of methane </dd>
#
#
# * **Other greenhouse gas emissions, HFC, PFC and SF<sub>6</sub> (thousand metric tons of CO<sub>2</sub> equivalent)**
# <dd> This group of gases is also called Fluorinated gases. Although, it has only small portion around 3 percent [1]. They are  referred to as High Global Warming Potential gases. One of the reason is their ability to deplete stratospheric ozone substances.</dd>
#
#
# * **Total greenhouse gas emissions (kt of CO<sub>2</sub> equivalent)**
# <dd>As known to many people, execessive greenhouse gas emission is the main cause of global warming and conseqeuntly climate change. This effect is caused due to these gases having greenhouse effect, or trapping heat from sunlight in the atmosphere.  The most abundant greenhouse gases in Earth's atmosphere are water vapor, carbon dioxide, methane, nitrous oxide, ozone, chlorofluorocarbons and Hydrofluorocarbons [2].</dd>
#
#
# * **CO<sub>2</sub> emissions (kt)**
# <dd> Carbon dioxide is the primary greenhouse gas emitted by human activites. The main sources are electricity, transportation and Industry [1]. </dd>
#
#
# [1] https://www.epa.gov/ghgemissions/overview-greenhouse-gases
#
# [2] https://en.wikipedia.org/wiki/Greenhouse_gas#Global_warming_potential
#
# [3] https://www.scientificamerican.com/article/deforestation-and-global-warming/
