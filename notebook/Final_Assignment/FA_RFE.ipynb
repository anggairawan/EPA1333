# %% [markdown]
# # Can we make a change on climate change?
# #### EPA1333 Final Assignment
#
# #### Angga Irawan (4516974), Priadi Teguh Wibowo (4625862)

# %% [markdown]
# # Introduction
#
# Global temperature rise, warming oceans, shrinking ice sheets, sea level rise are some evidences that the climate is changing. The suspected main cause of this phenomena is the greenhouse effect generated by the certain type of gases such as, Nitrous oxide, Carbon dioxide, and Methane.
#
# The long term consequences of this phenomena will affect the future condition of the Earth. Temperature will continue to increase, changes of precipitation patterns, also potentially more heat waves and hurricanes.
#
# In this project assignment, we are going to try to inspect a data mainly from World Bank data, take a closer look to the data and build a model of the climate change phenomena to foresee what is going to happen in the near future if we do not change the current trend or stay at our current state of environment system.
#
# We will restrict our investigation to one of the most prominent evidence of the climate change: Global Temperature, global surface temperature anomaly to be more precise. It refers to the deviation of the observed temperature from the reference or long term average. This observation can be used as diagnostic quantity of global-scale climate [1].
#
# We will analyse the dataset provided, perform a preliminary investigation to get a better understanding of the data and obtain the initial insight. We also will add the dataset with the information from another resources, do a selection of the appropiate information, and preprocess the data so that the data will not completely raw.
#
# Then, we could manipulate the data to form a so called features matrix and target vector and develop a model by using the various machine learning algorithm.
#
# Furthermore, we could perform a prediction of the future condition and explore more the parameter of the model so that we get a better explanation why the condition turn to be so.

# %% [markdown]
# <dl>
# The following are several research questions we are going to try to answer to help our analysis keep on track.
# <dd>1. Since when the climate change 'effectively' causing the global temperature anomaly to be warmer than the reference (1951-1980 average temperatures)? </dd>
# <dd>2. Which factors is contributing the most to global temperature anomaly?</dd>
# <dd>3. What will happen to global temperature anomaly if we do not change the trend of the current condition? </dd>
# </dl>
#
# [1] https://www.ncdc.noaa.gov/monitoring-references/faq/anomalies.php

# %% [markdown]
# # Data
#
# ## Climate change indicators
# The climate change data offered by World Bank contains a large set of indicators, such as for example CO2 emissions, population growth or renewable energy output. Values of these indicators are available per country and per year. The data is available in this URL: https://data.worldbank.org/topic/climate-change. It is also complemented by two files of metadata.

# %% [markdown]
# Import standard library to prepare the reading and loading process of the data.

# %%
# import standard library
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# Load the World Bank data as a dataframe.

# %%
# load world bank data
# skip the unneeded header
wb = pd.read_csv('world_bank/API_19_DS2_en_csv_v2.csv', sep=',', header=0, skiprows=3) 

# read_csv resulted in additional blank series at the last column -> drop the column
wb = wb.drop(wb.columns[[-1]], 1)

# display the head of dataframe
print("Dataframe shape:", wb.shape)
wb.head()
# Out:
# Dataframe shape: (21120, 61)
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW       Urban population (% of total)
# 1        Aruba          ABW                    Urban population
# 2        Aruba          ABW  Urban population growth (annual %)
# 3        Aruba          ABW                   Population, total
# 4        Aruba          ABW        Population growth (annual %)
#
#       Indicator Code          1960          1961          1962          1963  \
# 0  SP.URB.TOTL.IN.ZS     50.776000     50.761000     50.746000     50.730000
# 1        SP.URB.TOTL  27526.000000  28141.000000  28532.000000  28761.000000
# 2        SP.URB.GROW      3.117931      2.209658      1.379868      0.799404
# 3        SP.POP.TOTL  54211.000000  55438.000000  56225.000000  56695.000000
# 4        SP.POP.GROW      3.148037      2.238144      1.409622      0.832453
#
#            1964          1965      ...                 2007           2008  \
# 0     50.715000     50.700000      ...            44.147000      43.783000
# 1  28924.000000  29082.000000      ...         44686.000000   44375.000000
# 2      0.565140      0.544773      ...            -0.435429      -0.698401
# 3  57032.000000  57360.000000      ...        101220.000000  101353.000000
# 4      0.592649      0.573468      ...             0.384060       0.131311
#
#             2009           2010           2011           2012           2013  \
# 0      43.421000      43.059000      42.698000      42.364000      42.058000
# 1   44052.000000   43778.000000   43575.000000   43456.000000   43398.000000
# 2      -0.730549      -0.623935      -0.464782      -0.273466      -0.133557
# 3  101453.000000  101669.000000  102053.000000  102577.000000  103187.000000
# 4       0.098616       0.212680       0.376985       0.512145       0.592914
#
#             2014           2015           2016
# 0      41.779000      41.528000      41.304000
# 1   43365.000000   43331.000000   43296.000000
# 2      -0.076069      -0.078435      -0.080806
# 3  103795.000000  104341.000000  104822.000000
# 4       0.587492       0.524658       0.459929
#
# [5 rows x 61 columns]

# %% [markdown]
# The World Bank data consists of data for 57 years (1960-2016) of 264 countries with 80 indicators for each country. These data could be utilized as the initial data.

# %% [markdown]
# ### Countries Metadata

# %% [markdown]
# Load the additional csv file which contains the metadata of the countries on the main World Bank data.

# %%
#load country metadata
wb_meta_country = pd.read_csv('world_bank/Metadata_Country_API_19_DS2_en_csv_v2.csv', sep=',', header=0) 

# read_csv resulted in additional blank series at the last column -> drop the column
wb_meta_country = wb_meta_country.drop(wb_meta_country.columns[[-1]], 1)

# display the head of dataframe
wb_meta_country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName
# 0  SNA data for 2000-2011 are updated from offici...        Aruba
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan
# 2                                                NaN       Angola
# 3                                                NaN      Albania
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra

# %% [markdown]
# ### Indicator Metadata

# %% [markdown]
# We also have to include the another csv file containing the metadata of the indicator on the main World Bank data.

# %%
#load indicator metadata
wb_meta_indi = pd.read_csv('world_bank/Metadata_Indicator_API_19_DS2_en_csv_v2.csv', sep=',', header=0) 

# read_csv resulted in additional blank series at the last column -> drop the column
wb_meta_indi = wb_meta_indi.drop(wb_meta_indi.columns[[-1]], 1)

# display the head of dataframe
wb_meta_indi.head()
# Out:
#       INDICATOR_CODE                      INDICATOR_NAME  \
# 0  SP.URB.TOTL.IN.ZS       Urban population (% of total)
# 1        SP.URB.TOTL                    Urban population
# 2        SP.URB.GROW  Urban population growth (annual %)
# 3        SP.POP.TOTL                   Population, total
# 4        SP.POP.GROW        Population growth (annual %)
#
#                                          SOURCE_NOTE  \
# 0  Urban population refers to people living in ur...
# 1  Urban population refers to people living in ur...
# 2  Urban population refers to people living in ur...
# 3  Total population is based on the de facto defi...
# 4  Annual population growth rate for year t is th...
#
#                                  SOURCE_ORGANIZATION
# 0  The United Nations Population Divisions World ...
# 1  World Bank Staff estimates based on United Nat...
# 2  World Bank Staff estimates based on United Nat...
# 3  (1) United Nations Population Division. World ...
# 4  Derived from total population. Population sour...

# %% [markdown]
# # Additional Data

# %% [markdown]
# We need additional data from other resources to assist the previous obtained data as the additional feature, a potential label/output for the classification/regression, or a ground truth for the prediction.

# %% [markdown]
# ## Global Temperature Anomaly
#
# Global Temperature Anomaly data is provided by NASA, https://climate.nasa.gov/vital-signs/global-temperature/. This graph below illustrates the change in global surface temperature relative to 1951-1980 average temperatures. Sixteen of the 17 warmest years in the 136-year record all have occurred since 2001, with the exception of 1998. The year 2016 ranks as the warmest on record.
#
# Later, the global temperature anomaly from 1960 to 2016 will be used as target vector or output to be fitted in model.

# %%
df_tempe = pd.read_csv(
    'https://climate.nasa.gov/system/internal_resources/details/original/647_Global_Temperature_Data_File.txt', 
    sep="     ", 
    names=['year', 'annual mean', '5 year mean'],
    index_col = 'year',
    engine ='python')

# %%
df_tempe.plot(figsize = (16,5))
plt.ylabel('Temperature Anomaly (C)')
plt.title('Temperature Anomaly')

# %%
# slice the range of year, make suitable with the world bank data (provided since 1960)
df_tempe.index.name = None
df_tempe_since_1960 = df_tempe[80:]
df_tempe_since_1960.head()
# Out:
#       annual mean  5 year mean
# 1960        -0.02         0.03
# 1961         0.05         0.02
# 1962         0.03        -0.01
# 1963         0.06        -0.02
# 1964        -0.20        -0.03

# %% [markdown]
# ## Global Warming

# %% [markdown]
# We could find the start of the global warming approximately from the 5 years mean data when the anomaly is continuously higher than the temperature reference.

# %%
def strictly_increasing(L):
    return all(x<y for x, y in zip(L, L[1:]))

# %%
l = list(df_tempe[(df_tempe['5 year mean'] > 0)]['5 year mean'])
strictly_increasing(l)
# Out:
# False

# %% [markdown]
# ## Climate Change Performance Index
#
# Climate Change Performance Index (CCPI) is issued by Germanwatch and Climate Action Network Europe, https://germanwatch.org/en/13042. For the past 12 years, it has been keep tracking various countries’ efforts in combating climate change. On the basis of standardised criteria, the index evaluates and compares the climate protection performance of 58 countries that together are responsible for about 90% of global energy-related CO2 emissions. Unfortunately, we have to delete Taipei from the list as the World Bank data does not provide the data for the country.
#
# This data can be used to filter out the raw data / World Bank data with only countries that has most contribution to CO2 emission.

# %%
# load label Climate Change Performance Index
ccpi_country = pd.read_csv('CCPI/CCPI_2017.csv', sep=',', header=0) 

# rename the CCPI column to Country Name, so it could be 'merge' on this column name
ccpi_country.columns = ['Country Name', 'Category']
ccpi_country.head()
# Out:
#      Country Name Category
# 0          France     Good
# 1          Sweden     Good
# 2  United Kingdom     Good
# 3          Cyprus     Good
# 4         Morocco     Good

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Before jump in to the analysis of the data, we need to clean and preprocess the data first.

# %% [markdown]
# ## World Bank Data Interpolation

# %% [markdown]
# Many missing data are found in World Bank raw data. Thus, interpolation is performed to fill those missing data with appropriate values. We need to drop header and indicator of the dataframe so that we create a temporary dataframe with only numerical value of the World Bank data. We need this transformation to accomplish the interpolation.

# %%
# create column of years of the world bank data
years_column = wb.columns.values[range(4,61)]
years_column

# copy the content of the dataframe (to avoid copying the reference) for the interpolation
wb_prep = pd.DataFrame()
wb_prep = wb[years_column]

# reset the column (year) to integer
wb_prep.columns = range(0,57)

# display the dataframe
wb_prep.head(8)
# Out:
#              0             1             2             3             4   \
# 0     50.776000     50.761000     50.746000     50.730000     50.715000
# 1  27526.000000  28141.000000  28532.000000  28761.000000  28924.000000
# 2      3.117931      2.209658      1.379868      0.799404      0.565140
# 3  54211.000000  55438.000000  56225.000000  56695.000000  57032.000000
# 4      3.148037      2.238144      1.409622      0.832453      0.592649
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
#
#              5             6             7             8             9   \
# 0     50.700000     50.685000     50.670000     50.654000     50.639000
# 1  29082.000000  29253.000000  29416.000000  29575.000000  29738.000000
# 2      0.544773      0.586271      0.555661      0.539067      0.549628
# 3  57360.000000  57715.000000  58055.000000  58386.000000  58726.000000
# 4      0.573468      0.616991      0.587373      0.568530      0.580642
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
#
#        ...                   47             48             49             50  \
# 0      ...            44.147000      43.783000      43.421000      43.059000
# 1      ...         44686.000000   44375.000000   44052.000000   43778.000000
# 2      ...            -0.435429      -0.698401      -0.730549      -0.623935
# 3      ...        101220.000000  101353.000000  101453.000000  101669.000000
# 4      ...             0.384060       0.131311       0.098616       0.212680
# 5      ...                  NaN            NaN            NaN            NaN
# 6      ...                  NaN            NaN            NaN            NaN
# 7      ...            97.900000      97.800000      97.800000      97.700000
#
#               51             52             53             54             55  \
# 0      42.698000      42.364000      42.058000      41.779000      41.528000
# 1   43575.000000   43456.000000   43398.000000   43365.000000   43331.000000
# 2      -0.464782      -0.273466      -0.133557      -0.076069      -0.078435
# 3  102053.000000  102577.000000  103187.000000  103795.000000  104341.000000
# 4       0.376985       0.512145       0.592914       0.587492       0.524658
# 5            NaN            NaN            NaN            NaN            NaN
# 6            NaN            NaN            NaN            NaN            NaN
# 7      97.700000      97.700000      97.700000      97.700000      97.700000
#
#               56
# 0      41.304000
# 1   43296.000000
# 2      -0.080806
# 3  104822.000000
# 4       0.459929
# 5            NaN
# 6            NaN
# 7            NaN
#
# [8 rows x 57 columns]

# %% [markdown]
# As we can see from dataframe above, we have a particular row with NaN as its value, both partially or fully for entire row. We will perform the interpolation only to the partial one, see row 7 for an example.

# %%
# interpolate the data in row direction also in both direction within range limit
wb_interpolated = wb_prep.interpolate(method='linear',limit_direction='both',limit=56,axis=1)

# %%
# show the interpolation results
wb_interpolated.head(8)
# Out:
#              0             1             2             3             4   \
# 0     50.776000     50.761000     50.746000     50.730000     50.715000
# 1  27526.000000  28141.000000  28532.000000  28761.000000  28924.000000
# 2      3.117931      2.209658      1.379868      0.799404      0.565140
# 3  54211.000000  55438.000000  56225.000000  56695.000000  57032.000000
# 4      3.148037      2.238144      1.409622      0.832453      0.592649
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7     98.600000     98.600000     98.600000     98.600000     98.600000
#
#              5             6             7             8             9   \
# 0     50.700000     50.685000     50.670000     50.654000     50.639000
# 1  29082.000000  29253.000000  29416.000000  29575.000000  29738.000000
# 2      0.544773      0.586271      0.555661      0.539067      0.549628
# 3  57360.000000  57715.000000  58055.000000  58386.000000  58726.000000
# 4      0.573468      0.616991      0.587373      0.568530      0.580642
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7     98.600000     98.600000     98.600000     98.600000     98.600000
#
#        ...                   47             48             49             50  \
# 0      ...            44.147000      43.783000      43.421000      43.059000
# 1      ...         44686.000000   44375.000000   44052.000000   43778.000000
# 2      ...            -0.435429      -0.698401      -0.730549      -0.623935
# 3      ...        101220.000000  101353.000000  101453.000000  101669.000000
# 4      ...             0.384060       0.131311       0.098616       0.212680
# 5      ...                  NaN            NaN            NaN            NaN
# 6      ...                  NaN            NaN            NaN            NaN
# 7      ...            97.900000      97.800000      97.800000      97.700000
#
#               51             52             53             54             55  \
# 0      42.698000      42.364000      42.058000      41.779000      41.528000
# 1   43575.000000   43456.000000   43398.000000   43365.000000   43331.000000
# 2      -0.464782      -0.273466      -0.133557      -0.076069      -0.078435
# 3  102053.000000  102577.000000  103187.000000  103795.000000  104341.000000
# 4       0.376985       0.512145       0.592914       0.587492       0.524658
# 5            NaN            NaN            NaN            NaN            NaN
# 6            NaN            NaN            NaN            NaN            NaN
# 7      97.700000      97.700000      97.700000      97.700000      97.700000
#
#               56
# 0      41.304000
# 1   43296.000000
# 2      -0.080806
# 3  104822.000000
# 4       0.459929
# 5            NaN
# 6            NaN
# 7      97.700000
#
# [8 rows x 57 columns]

# %% [markdown]
# The row now are filled out by values from the interpolation results. As for the case where the entire row is completely fill out by NaN, we will handle it later.

# %% [markdown]
# A new dataframe is created to accomodate the new interpolated values.

# %%
# create a new dataframe to avoid overwriting the original dataframe
wb_inter = pd.DataFrame()
wb_inter = wb[wb.columns.values]

# replace wb_inter annual value with the interpolated one
wb_inter[list(wb.columns.values[range(4,61)])] = wb_interpolated[list(range(0,57))]

# now we have interpolated world bank data
wb_inter.head(8)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
# 5        Aruba          ABW
# 6        Aruba          ABW
# 7        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0                      Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 1                                   Urban population        SP.URB.TOTL
# 2                 Urban population growth (annual %)        SP.URB.GROW
# 3                                  Population, total        SP.POP.TOTL
# 4                       Population growth (annual %)        SP.POP.GROW
# 5  Poverty headcount ratio at $1.90 a day (2011 P...        SI.POV.DDAY
# 6  Prevalence of underweight, weight for age (% o...     SH.STA.MALN.ZS
# 7  Improved sanitation facilities (% of populatio...        SH.STA.ACSN
#
#            1960          1961          1962          1963          1964  \
# 0     50.776000     50.761000     50.746000     50.730000     50.715000
# 1  27526.000000  28141.000000  28532.000000  28761.000000  28924.000000
# 2      3.117931      2.209658      1.379868      0.799404      0.565140
# 3  54211.000000  55438.000000  56225.000000  56695.000000  57032.000000
# 4      3.148037      2.238144      1.409622      0.832453      0.592649
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7     98.600000     98.600000     98.600000     98.600000     98.600000
#
#            1965      ...                 2007           2008           2009  \
# 0     50.700000      ...            44.147000      43.783000      43.421000
# 1  29082.000000      ...         44686.000000   44375.000000   44052.000000
# 2      0.544773      ...            -0.435429      -0.698401      -0.730549
# 3  57360.000000      ...        101220.000000  101353.000000  101453.000000
# 4      0.573468      ...             0.384060       0.131311       0.098616
# 5           NaN      ...                  NaN            NaN            NaN
# 6           NaN      ...                  NaN            NaN            NaN
# 7     98.600000      ...            97.900000      97.800000      97.800000
#
#             2010           2011           2012           2013           2014  \
# 0      43.059000      42.698000      42.364000      42.058000      41.779000
# 1   43778.000000   43575.000000   43456.000000   43398.000000   43365.000000
# 2      -0.623935      -0.464782      -0.273466      -0.133557      -0.076069
# 3  101669.000000  102053.000000  102577.000000  103187.000000  103795.000000
# 4       0.212680       0.376985       0.512145       0.592914       0.587492
# 5            NaN            NaN            NaN            NaN            NaN
# 6            NaN            NaN            NaN            NaN            NaN
# 7      97.700000      97.700000      97.700000      97.700000      97.700000
#
#             2015           2016
# 0      41.528000      41.304000
# 1   43331.000000   43296.000000
# 2      -0.078435      -0.080806
# 3  104341.000000  104822.000000
# 4       0.524658       0.459929
# 5            NaN            NaN
# 6            NaN            NaN
# 7      97.700000      97.700000
#
# [8 rows x 61 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Filter the World Bank data with CCPI countries

# %% [markdown]
# New dataframe which contains only the data from countries being mentioned in CCPI document is created.

# %%
# create a df of countries from CCPI results countries
df_ccpi = pd.DataFrame()
for country in country_class_y['Country Name']:
    # filter the CCPI countries
    
    # not interpolated
    # df1 = wb[wb['Country Name'] == country]
    
    # take it from the interpolated one
    df1 = wb_inter[wb_inter['Country Name'] == country]

    # append to the df
    df_ccpi = pd.concat( [df_ccpi,df1], ignore_index=True, axis=0)
    
df_ccpi[:8]
# Out:
#   Country Name Country Code  \
# 0       France          FRA
# 1       France          FRA
# 2       France          FRA
# 3       France          FRA
# 4       France          FRA
# 5       France          FRA
# 6       France          FRA
# 7       France          FRA
#
#                                       Indicator Name     Indicator Code  \
# 0                      Urban population (% of total)  SP.URB.TOTL.IN.ZS
# 1                                   Urban population        SP.URB.TOTL
# 2                 Urban population growth (annual %)        SP.URB.GROW
# 3                                  Population, total        SP.POP.TOTL
# 4                       Population growth (annual %)        SP.POP.GROW
# 5  Poverty headcount ratio at $1.90 a day (2011 P...        SI.POV.DDAY
# 6  Prevalence of underweight, weight for age (% o...     SH.STA.MALN.ZS
# 7  Improved sanitation facilities (% of populatio...        SH.STA.ACSN
#
#            1960          1961          1962          1963          1964  \
# 0  6.188000e+01  6.260700e+01  6.348900e+01  6.470200e+01  6.589800e+01
# 1  2.896865e+07  2.970374e+07  3.055068e+07  3.157696e+07  3.258617e+07
# 2  2.424503e+00  2.505858e+00  2.811428e+00  3.304057e+00  3.146026e+00
# 3  4.681424e+07  4.744475e+07  4.811965e+07  4.880368e+07  4.944940e+07
# 4  1.229610e+00  1.337853e+00  1.412470e+00  1.411512e+00  1.314427e+00
# 5  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01  1.000000e-01
# 6           NaN           NaN           NaN           NaN           NaN
# 7  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01
#
#            1965      ...               2007          2008          2009  \
# 0  6.707100e+01      ...       7.762100e+01  7.786400e+01  7.810600e+01
# 1  3.355144e+07      ...       4.969004e+07  5.012494e+07  5.054008e+07
# 2  2.919203e+00      ...       9.335545e-01  8.714278e-01  8.248035e-01
# 3  5.002377e+07      ...       6.401623e+07  6.437499e+07  6.470704e+07
# 4  1.154839e+00      ...       6.187115e-01  5.588574e-01  5.144864e-01
# 5  1.000000e-01      ...       0.000000e+00  0.000000e+00  5.000000e-02
# 6           NaN      ...                NaN           NaN           NaN
# 7  9.870000e+01      ...       9.870000e+01  9.870000e+01  9.870000e+01
#
#            2010          2011          2012          2013          2014  \
# 0  7.834500e+01  7.858400e+01  7.882000e+01  7.905500e+01  7.928900e+01
# 1  5.094580e+07  5.134897e+07  5.175305e+07  5.217517e+07  5.259394e+07
# 2  7.995637e-01  7.882418e-01  7.838471e-01  8.123421e-01  7.994288e-01
# 3  6.502751e+07  6.534278e+07  6.565979e+07  6.599857e+07  6.633196e+07
# 4  4.940375e-01  4.836449e-01  4.839823e-01  5.146361e-01  5.038712e-01
# 5  1.000000e-01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 6           NaN           NaN           NaN           NaN           NaN
# 7  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01  9.870000e+01
#
#            2015          2016
# 0  7.952000e+01  7.975000e+01
# 1  5.297946e+07  5.334965e+07
# 2  7.303273e-01  6.963089e-01
# 3  6.662407e+07  6.689611e+07
# 4  4.394107e-01  4.074910e-01
# 5  0.000000e+00  0.000000e+00
# 6           NaN           NaN
# 7  9.870000e+01  9.870000e+01
#
# [8 rows x 61 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Removing Missing Indicator (NaN for entire row)

# %% [markdown]
# Check the data for each country which the entire years of a indicator are missing. We will remove this indicator from the dataframe so that it will not affect the model negatively.

# %%
import operator

# saved indicator
list_deleted_indi = []
list_tuple_country_del_indi = []
for c, i in enumerate(range(0,4480,80)):
    # print(c, df_ccpi['Country Name'][i],df_ccpi[i:i+80].isnull().any(axis=1).sum())
    list_tuple_country_del_indi.append((df_ccpi['Country Name'][i], df_ccpi[i:i+80].isnull().any(axis=1).sum())) 
    for i in df_ccpi[i:i+80]['Indicator Name'][df_ccpi[i:i+80].isnull().any(axis=1)]:
        # print(i)
        list_deleted_indi.append(i)    

# list_tuple_country_del_indi.sort(key=operator.itemgetter(1))
df_tuple_cdi = pd.DataFrame(list_tuple_country_del_indi, columns = ['Country Name','Number of Missing Indicator'])
df_tuple_cdi = df_tuple_cdi.set_index('Country Name')
# df_tuple_cdi.plot(kind = 'bar', figsize=(16,4))

# %%
from bokeh.io import output_notebook
from bokeh.charts import Bar, show

output_notebook()
NA_per_country = Bar(df_tuple_cdi, 'Country Name', values='Number of Missing Indicator', 
        title="Number of Missing Indicator for Each Country",
        plot_width=900, plot_height=450, legend=False)
show(NA_per_country)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2f4f0cb7-e695-41e2-b368-26f855503132">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9036c034-b9a6-4c81-96bb-52728d06493e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9036c034-b9a6-4c81-96bb-52728d06493e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9036c034-b9a6-4c81-96bb-52728d06493e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9036c034-b9a6-4c81-96bb-52728d06493e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d63e901f-5b87-408e-b2c7-a7e657395181":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["United Kingdom"],"chart_index":[{"Country Name":"United Kingdom"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":[{"Country Name":"United Kingdom"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["United Kingdom"],"y":[2.0]}},"id":"2a62fb32-30cb-487a-b23a-47c777ebbe77","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Norway"],"chart_index":[{"Country Name":"Norway"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":[{"Country Name":"Norway"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Norway"],"y":[2.0]}},"id":"a9f8a1f2-7c3b-462c-83eb-027481faf33f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Finland"],"chart_index":[{"Country Name":"Finland"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":[{"Country Name":"Finland"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Finland"],"y":[1.5]}},"id":"822f591c-bd23-4d25-a90a-ef23683b0aea","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Sweden"],"chart_index":[{"Country Name":"Sweden"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":[{"Country Name":"Sweden"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Sweden"],"y":[1.5]}},"id":"feb4321d-8ac2-4b3b-999e-a5295225c381","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Bulgaria"],"chart_index":[{"Country Name":"Bulgaria"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"Country Name":"Bulgaria"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Bulgaria"],"y":[1.0]}},"id":"47120f77-f8fa-4c8a-b2c6-33a7e532b2d7","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Cyprus"],"chart_index":[{"Country Name":"Cyprus"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6.0],"label":[{"Country Name":"Cyprus"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Cyprus"],"y":[3.0]}},"id":"b1d283bd-0e93-4d79-a31e-a454684b5740","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"359ebc8f-1e1b-4b20-81f2-486af40b55bd","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name":["Germany"],"chart_index":[{"Country Name":"Germany"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"Country Name":"Germany"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Germany"],"y":[1.0]}},"id":"bea211e1-3879-4080-b39d-7a7e4845aa23","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"bea211e1-3879-4080-b39d-7a7e4845aa23","type":"ColumnDataSource"},"glyph":{"id":"2378a78f-14fd-4d17-ad77-3813f93b076a","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"6b1b5f28-545d-4de6-9dc6-895f374c1597","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Country Name" ...

# %%
from collections import Counter
deleted_indi_counts = Counter(list_deleted_indi)
df_dic = pd.DataFrame.from_dict(deleted_indi_counts, orient='index')
df_dic.columns = ['Number of Countries']

p = Bar(df_dic, values='Number of Countries', 
        title="Number of Countries which Missing the Indicator",
        plot_width=900, plot_height=700, legend=False)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="55376594-fb92-41a0-9b96-7ae833208b43"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("55376594-fb92-41a0-9b96-7ae833208b43");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55376594-fb92-41a0-9b96-7ae833208b43");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55376594-fb92-41a0-9b96-7ae833208b43' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"23753acb-01c3-4eb2-b2a4-85bd27da3d80":{"roots":{"references":[{"attributes":{"overlay":{"id":"c32047bb-c32b-4a60-9f66-ace6473b7f81","type":"BoxAnnotation"},"plot":{"id":"a97856ff-e9e6-4fc5-bb0a-c2280031a2b9","subtype":"Chart","type":"Plot"}},"id":"0a433f3e-4f29-4230-8041-1798dba6bf82","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Primary completion rate, total (% of relevant age group)"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"index":["Primary completion rate, total (% of relevant age group)"],"label":[{"index":"Primary completion rate, total (% of relevant age group)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Primary completion rate, total (% of relevant age group)"],"y":[2.0]}},"id":"dd670cea-459c-44b1-b5df-a80d302b4b9e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"index":["Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)"],"label":[{"index":"Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)"],"y":[2.0]}},"id":"e1ef8a99-a08a-4e3c-a7de-df159b242da6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d506b25-945a-44ec-9056-ed05c39e0aad","type":"Rect"},{"attributes":{"plot":{"id":"a97856ff-e9e6-4fc5-bb0a-c2280031a2b9","subtype":"Chart","type":"Plot"}},"id":"b7c7d404-2b1c-406b-a190-a74cfbfbcc3c","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Population in urban agglomerations of more than 1 million (% of total population)"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11.0],"index":["Population in urban agglomerations of more than 1 million (% of total population)"],"label":[{"index":"Population in urban agglomerations of more than 1 million (% of total population)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Population in urban agglomerations of more than 1 million (% of total population)"],"y":[5.5]}},"id":"498065f1-0436-4b10-82d4-e5b1e5a4c323","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f0d83059-4b54-4723-bff0-8e17fe3cc379","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"GHG net emissions/removals by LUCF (Mt of CO2 equivalent)"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"index":["GHG net emissions/removals by LUCF (Mt of CO2 equivalent)"],"label":[{"index":"GHG net emissions/removals by LUCF (Mt of CO2 equivalent)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["GHG net emissions/removals by LUCF (Mt of CO2 equivalent)"],"y":[1.5]}},"id":"1b87200a-3b9c-4a35-afda-c7ab308d5cdd","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e8b8bf81-adc6-47da-8f90-d5f401c92ce3","type":"PanTool"},{"id":"7a319738-9505-4b51-8d89-877a25282d79","type":"WheelZoomTool"},{"id":"0a433f3e-4f29-4230 ...

# %%
# Scatter
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(df['Age'],df['Sales']) #You can also add more variables here to represent color and size.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2b6d07c685f1> in <module>()
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(1,1,1)
# ----> 3 ax.scatter(df['Age'],df['Sales']) #You can also add more variables here to represent color and size.
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Filter the data frame so it only consists of the indicators which are complete for the entire year (1960-2016).

# %%
len(set(list_deleted_indi))
# Out:
# 24

# %% [markdown]
# We will have to remove 24 indicators from the data. It leaves us with the remaining 56 indicators.

# %%
df_ccpi_clean = pd.DataFrame()

# initialize the flag of saved indicator
array_flag = np.ones((len(df_ccpi)), dtype=bool)

# transfom it to series
series_flag = pd.Series(data = array_flag, index=range(len(df_ccpi)))

# filter the indicator
for indi in sorted(set(list_deleted_indi)):
    series_flag = (series_flag & (df_ccpi['Indicator Name'] != indi))

# filter the df
df_ccpi_clean_reset = df_ccpi[series_flag]

print('Number of row with missing value:', df_ccpi_clean_reset.isnull().any().sum())
# Out:
# Number of row with missing value: 0

# %% [markdown]
# As we could see from dataframe calculation above, we do not have missing value anymore.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Averaging and Summing the Features

# %% [markdown]
# We already have done preprocessing to our data, but to make it even more meaningful as the input features for the model we need to 'engineer' the data. We will sum up or re-average the data as the appropriate interaction to do based on the source note on the countries metadata. We might even remove the data if the data is considered as redundant or are already represented by another feature. The information of the metadata is concluded as the csv file below.

# %%
df_feature_select = pd.read_csv('world_bank/feature_engineering.csv',sep=',', header=0)

# %%
df_feature_select.head()
# Out:
#                        Indicator Name Feature Interaction
# 0       Urban population (% of total)              remove
# 1                    Urban population                 sum
# 2  Urban population growth (annual %)             average
# 3                   Population, total                 sum
# 4        Population growth (annual %)             average

# %%
df_ccpi_feature_label = pd.merge(df_ccpi_clean_reset, df_feature_select, 
                                 on = 'Indicator Name', how="inner")

print('Dataframe shape:', df_ccpi_feature_label.shape)
df_ccpi_feature_label.head()
# Out:
# Dataframe shape: (2856, 62)
#      Country Name Country Code                 Indicator Name  \
# 0          France          FRA  Urban population (% of total)
# 1          Sweden          SWE  Urban population (% of total)
# 2  United Kingdom          GBR  Urban population (% of total)
# 3          Cyprus          CYP  Urban population (% of total)
# 4      Luxembourg          LUX  Urban population (% of total)
#
#       Indicator Code    1960    1961    1962    1963    1964    1965  \
# 0  SP.URB.TOTL.IN.ZS  61.880  62.607  63.489  64.702  65.898  67.071
# 1  SP.URB.TOTL.IN.ZS  72.490  73.295  74.271  75.223  76.153  77.056
# 2  SP.URB.TOTL.IN.ZS  78.444  78.374  78.237  78.099  77.960  77.821
# 3  SP.URB.TOTL.IN.ZS  35.628  36.175  36.674  37.176  37.681  38.188
# 4  SP.URB.TOTL.IN.ZS  69.556  69.927  70.443  70.953  71.459  71.958
#
#           ...             2008    2009    2010    2011    2012    2013  \
# 0         ...           77.864  78.106  78.345  78.584  78.820  79.055
# 1         ...           84.746  84.902  85.056  85.210  85.363  85.514
# 2         ...           80.757  81.031  81.302  81.570  81.834  82.092
# 3         ...           67.839  67.695  67.551  67.406  67.261  67.133
# 4         ...           87.800  88.178  88.547  88.906  89.247  89.568
#
#      2014    2015    2016  Feature Interaction
# 0  79.289  79.520  79.750               remove
# 1  85.665  85.815  85.964               remove
# 2  82.345  82.592  82.835               remove
# 3  67.019  66.921  66.840               remove
# 4  89.872  90.160  90.432               remove
#
# [5 rows x 62 columns]

# %%
df_ccpi_feature_label_removed = df_ccpi_feature_label [df_ccpi_feature_label['Feature Interaction'] != 'remove']
print('Dataframe shape:', df_ccpi_feature_label_removed.shape)
df_ccpi_feature_label_removed.head()
# Out:
# Dataframe shape: (2408, 62)
#       Country Name Country Code    Indicator Name Indicator Code        1960  \
# 56          France          FRA  Urban population    SP.URB.TOTL  28968650.0
# 57          Sweden          SWE  Urban population    SP.URB.TOTL   5425627.0
# 58  United Kingdom          GBR  Urban population    SP.URB.TOTL  41104656.0
# 59          Cyprus          CYP  Urban population    SP.URB.TOTL    204124.0
# 60      Luxembourg          LUX  Urban population    SP.URB.TOTL    218385.0
#
#           1961        1962        1963        1964        1965  \
# 56  29703735.0  30550684.0  31576957.0  32586168.0  33551445.0
# 57   5511783.0   5616067.0   5720204.0   5834351.0   5959398.0
# 58  41381472.0  41661202.0  41900114.0  42098400.0  42294196.0
# 59    208511.0    211862.0    214845.0    218032.0    221859.0
# 60    221560.0    225946.0    229959.0    234207.0    238541.0
#
#            ...                 2008        2009        2010        2011  \
# 56         ...           50124942.0  50540084.0  50945804.0  51348967.0
# 57         ...            7813274.0   7894625.0   7976659.0   8051674.0
# 58         ...           49913475.0  50463084.0  51030310.0  51600299.0
# 59         ...             733722.0    743343.0    751577.0    758206.0
# 60         ...             429035.0    438935.0    448892.0    460842.0
#
#           2012        2013        2014        2015        2016  \
# 56  51753046.0  52175170.0  52593945.0  52979459.0  53349647.0
# 57   8126023.0   8209668.0   8306173.0   8409171.0   8513120.0
# 58  52128504.0  52644143.0  53205707.0  53791229.0  54370607.0
# 59    763454.0    767932.0    772266.0    776943.0    782112.0
# 60    473853.0    486677.0    499975.0    513555.0    527193.0
#
#     Feature Interaction
# 56                  sum
# 57                  sum
# 58                  sum
# 59                  sum
# 60                  sum
#
# [5 rows x 62 columns]

# %% [markdown]
# The number of features to be summed.

# %%
set_indi_sum = set(df_ccpi_feature_label_removed[df_ccpi_feature_label_removed['Feature Interaction'] == 'sum']['Indicator Name'])
len(set_indi_sum)
# Out:
# 14

# %% [markdown]
# The number of features to be averaged.

# %%
set_indi_average = set(df_ccpi_feature_label_removed[df_ccpi_feature_label_removed['Feature Interaction'] == 'average']['Indicator Name'])
len(set_indi_average)
# Out:
# 29

# %% [markdown]
# Generate new engineered dataframe. First we append the dataframe with the averaged features.

# %%
df_ccpi_feature_processed = pd.DataFrame()

for indi in set_indi_average:
    df_indi = df_ccpi_feature_label_removed[(df_ccpi_feature_label_removed['Feature Interaction'] == 'average') & (df_ccpi_feature_label_removed['Indicator Name'] == indi)]
    df_indi_ave = (df_indi.sum(axis = 0)) 
    
    df_ccpi_feature_processed[indi] = df_indi_ave[4:-1]/len(country_class_y)
    
print('Dataframe shape:',df_ccpi_feature_processed.shape)    
df_ccpi_feature_processed.head()
# Out:
# Dataframe shape: (57, 29)
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                             79.458
# 1961                                             79.458
# 1962                                             79.458
# 1963                                             79.458
# 1964                                             79.458
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                             182.64
# 1961                                             182.64
# 1962                                             182.64
# 1963                                             182.64
# 1964                                             182.64
#
#      Improved water source, urban (% of urban population with access)  \
# 1960                                            98.1536
# 1961                                            98.1536
# 1962                                            98.1536
# 1963                                            98.1536
# 1964                                            98.1536
#
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.47175
# 1961                                  0.47175
# 1962                                  0.47175
# 1963                                  0.47175
# 1964                                  0.47175
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.50179
# 1961                                          4.50179
# 1962                                          4.50179
# 1963                                          4.50179
# 1964                                          4.50179
#
#      Mortality rate, under-5 (per 1,000 live births)  \
# 1960                                         73.7929
# 1961                                         72.1464
# 1962                                         70.5768
# 1963                                         69.0786
# 1964                                         67.5839
#
#      Renewable electricity output (% of total electricity output)  \
# 1960                                            21.8154
# 1961                                            21.8154
# 1962                                            21.8154
# 1963                                            21.8154
# 1964                                            21.8154
#
#      Arable land (% of land area) CO2 emissions (metric tons per capita)  \
# 1960                      23.1082                                5.66017
# 1961                      23.1082                                5.70286
# 1962                      23.0374                                5.84855
# 1963                      22.9832                                6.02533
# 1964                       22.902                                6.23069
#
#      Terrestrial protected areas (% of total land area)  \
# 1960                                            7.80804
# 1961                                            7.80804
# 1962                                            7.80804
# 1963                                            7.80804
# 1964                                            7.80804
#
#                              ...                           \
# 1960                         ...
# 1961                         ...
# 1962                         ...
# 1963                         ...
# 1964                         ...
#
#      Population growth (annual %) Urban population growth (annual %)  \
# 1960                      1.71507                             3.1037
# 1961                      1.51683                            2.94133
# 1962                      1.51251                            2.97675
# 1963                      1.49774                            2.96471
# 1964                      1.48225                             2.9412
#
#      Terrestrial and marine protected areas (% of total territorial area)  \
# 1960                                            5.15786
# 1961                                            5.15786
# 1962                                            5.15786
# 1963                                            5.15786
# 1964                                            5.15786
#
#      CO2 emissions (kg per PPP $ of GDP)  \
# 1960                            0.775283
# 1961                            0.775283
# 1962                            0.775283
# 1963                            0.775283
# 1964                            0.775283
#
#      Nitrous oxide emissions (% change from 1990)  \
# 1960                                     -1.78695
# 1961                                     -1.78695
# 1962                                     -1.78695
# 1963                                     -1.78695
# 1964                                     -1.78695
#
#      CO2 intensity (kg per kg of oil equivalent energy use)  \
# 1960                                            3.04315
# 1961                                            3.03726
# 1962                                            3.03768
# 1963                                            3.04045
# 1964                                            3.04117
#
#      Energy use (kg of oil equivalent per capita)  \
# 1960                                      2166.84
# 1961                                      2182.47
# 1962                                      2225.03
# 1963                                      2283.57
# 1964                                      2332.27
#
#      Improved water source (% of population with access)  \
# 1960                                            94.5607
# 1961                                            94.5607
# 1962                                            94.5607
# 1963                                            94.5607
# 1964                                            94.5607
#
#      Electricity production from nuclear sources (% of total)  \
# 1960                                            2.45016
# 1961                                            2.45809
# 1962                                            2.47409
# 1963                                            2.51196
# 1964                                            2.57813
#
#      Electricity production from oil sources (% of total)
# 1960                                            23.9234
# 1961                                            24.4755
# 1962                                            25.1127
# 1963                                            25.7103
# 1964                                            26.8022
#
# [5 rows x 29 columns]

# %% [markdown]
# Calculate and append the summed features.

# %%
for indi in set_indi_sum:
    df_indi = df_ccpi_feature_label_removed[(df_ccpi_feature_label_removed['Feature Interaction'] == 'sum') & (df_ccpi_feature_label_removed['Indicator Name'] == indi)]
    df_indi_sum = df_indi.sum(axis = 0)
    
    df_ccpi_feature_processed[indi] = df_indi_sum[4:-1]
    
print('Dataframe shape:',df_ccpi_feature_processed.shape)    
df_ccpi_feature_processed.head()
# Out:
# Dataframe shape: (57, 43)
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                             79.458
# 1961                                             79.458
# 1962                                             79.458
# 1963                                             79.458
# 1964                                             79.458
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                             182.64
# 1961                                             182.64
# 1962                                             182.64
# 1963                                             182.64
# 1964                                             182.64
#
#      Improved water source, urban (% of urban population with access)  \
# 1960                                            98.1536
# 1961                                            98.1536
# 1962                                            98.1536
# 1963                                            98.1536
# 1964                                            98.1536
#
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.47175
# 1961                                  0.47175
# 1962                                  0.47175
# 1963                                  0.47175
# 1964                                  0.47175
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.50179
# 1961                                          4.50179
# 1962                                          4.50179
# 1963                                          4.50179
# 1964                                          4.50179
#
#      Mortality rate, under-5 (per 1,000 live births)  \
# 1960                                         73.7929
# 1961                                         72.1464
# 1962                                         70.5768
# 1963                                         69.0786
# 1964                                         67.5839
#
#      Renewable electricity output (% of total electricity output)  \
# 1960                                            21.8154
# 1961                                            21.8154
# 1962                                            21.8154
# 1963                                            21.8154
# 1964                                            21.8154
#
#      Arable land (% of land area) CO2 emissions (metric tons per capita)  \
# 1960                      23.1082                                5.66017
# 1961                      23.1082                                5.70286
# 1962                      23.0374                                5.84855
# 1963                      22.9832                                6.02533
# 1964                       22.902                                6.23069
#
#      Terrestrial protected areas (% of total land area)  \
# 1960                                            7.80804
# 1961                                            7.80804
# 1962                                            7.80804
# 1963                                            7.80804
# 1964                                            7.80804
#
#                                 ...                              \
# 1960                            ...
# 1961                            ...
# 1962                            ...
# 1963                            ...
# 1964                            ...
#
#      Total greenhouse gas emissions (kt of CO2 equivalent)  \
# 1960                                        2.15502e+07
# 1961                                        2.15502e+07
# 1962                                        2.15502e+07
# 1963                                        2.15502e+07
# 1964                                        2.15502e+07
#
#      SF6 gas emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                             107782
# 1961                                             107782
# 1962                                             107782
# 1963                                             107782
# 1964                                             107782
#
#      Population, total Agricultural land (sq. km)  \
# 1960       2.40932e+09                3.02061e+07
# 1961        2.4345e+09                3.02061e+07
# 1962       2.47101e+09                3.02598e+07
# 1963       2.51917e+09                3.03205e+07
# 1964        2.5672e+09                3.03669e+07
#
#      Electricity production from renewable sources, excluding hydroelectric (kWh)  \
# 1960                                          3.791e+09
# 1961                                          4.179e+09
# 1962                                          4.548e+09
# 1963                                          5.113e+09
# 1964                                          5.404e+09
#
#      Annual freshwater withdrawals, total (billion cubic meters)  \
# 1960                                             2338.8
# 1961                                             2338.8
# 1962                                             2338.8
# 1963                                             2338.8
# 1964                                             2338.8
#
#      Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.59218e+06
# 1961                                        1.59218e+06
# 1962                                        1.59218e+06
# 1963                                        1.59218e+06
# 1964                                        1.59218e+06
#
#      Urban population Forest area (sq. km)  \
# 1960      8.78697e+08           2.8688e+07
# 1961      9.01916e+08           2.8688e+07
# 1962      9.27114e+08           2.8688e+07
# 1963      9.54992e+08           2.8688e+07
# 1964      9.83405e+08           2.8688e+07
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent)
# 1960                                             104428
# 1961                                             104428
# 1962                                             104428
# 1963                                             104428
# 1964                                             104428
#
# [5 rows x 43 columns]

# %% [markdown]
# # Training Set

# %% [markdown]
# In this step, input feature matrix and target vector are established from previously loaded data to train the model of Linear Regression.

# %% [markdown]
# ## Feature Matrix

# %% [markdown]
# Input matrix is obtained from world bank data, with rows as year from 1960 to 2016 and columns as indicators for each countries.

# %%
X_tempe_train = df_ccpi_feature_processed

dataset_tempe = X_tempe_train[X_tempe_train.columns.values]

print('Dataframe shape:', dataset_tempe.shape)
dataset_tempe.head()
# Out:
# Dataframe shape: (57, 43)
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                             79.458
# 1961                                             79.458
# 1962                                             79.458
# 1963                                             79.458
# 1964                                             79.458
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                             182.64
# 1961                                             182.64
# 1962                                             182.64
# 1963                                             182.64
# 1964                                             182.64
#
#      Improved water source, urban (% of urban population with access)  \
# 1960                                            98.1536
# 1961                                            98.1536
# 1962                                            98.1536
# 1963                                            98.1536
# 1964                                            98.1536
#
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.47175
# 1961                                  0.47175
# 1962                                  0.47175
# 1963                                  0.47175
# 1964                                  0.47175
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.50179
# 1961                                          4.50179
# 1962                                          4.50179
# 1963                                          4.50179
# 1964                                          4.50179
#
#      Mortality rate, under-5 (per 1,000 live births)  \
# 1960                                         73.7929
# 1961                                         72.1464
# 1962                                         70.5768
# 1963                                         69.0786
# 1964                                         67.5839
#
#      Renewable electricity output (% of total electricity output)  \
# 1960                                            21.8154
# 1961                                            21.8154
# 1962                                            21.8154
# 1963                                            21.8154
# 1964                                            21.8154
#
#      Arable land (% of land area) CO2 emissions (metric tons per capita)  \
# 1960                      23.1082                                5.66017
# 1961                      23.1082                                5.70286
# 1962                      23.0374                                5.84855
# 1963                      22.9832                                6.02533
# 1964                       22.902                                6.23069
#
#      Terrestrial protected areas (% of total land area)  \
# 1960                                            7.80804
# 1961                                            7.80804
# 1962                                            7.80804
# 1963                                            7.80804
# 1964                                            7.80804
#
#                                 ...                              \
# 1960                            ...
# 1961                            ...
# 1962                            ...
# 1963                            ...
# 1964                            ...
#
#      Total greenhouse gas emissions (kt of CO2 equivalent)  \
# 1960                                        2.15502e+07
# 1961                                        2.15502e+07
# 1962                                        2.15502e+07
# 1963                                        2.15502e+07
# 1964                                        2.15502e+07
#
#      SF6 gas emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                             107782
# 1961                                             107782
# 1962                                             107782
# 1963                                             107782
# 1964                                             107782
#
#      Population, total Agricultural land (sq. km)  \
# 1960       2.40932e+09                3.02061e+07
# 1961        2.4345e+09                3.02061e+07
# 1962       2.47101e+09                3.02598e+07
# 1963       2.51917e+09                3.03205e+07
# 1964        2.5672e+09                3.03669e+07
#
#      Electricity production from renewable sources, excluding hydroelectric (kWh)  \
# 1960                                          3.791e+09
# 1961                                          4.179e+09
# 1962                                          4.548e+09
# 1963                                          5.113e+09
# 1964                                          5.404e+09
#
#      Annual freshwater withdrawals, total (billion cubic meters)  \
# 1960                                             2338.8
# 1961                                             2338.8
# 1962                                             2338.8
# 1963                                             2338.8
# 1964                                             2338.8
#
#      Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.59218e+06
# 1961                                        1.59218e+06
# 1962                                        1.59218e+06
# 1963                                        1.59218e+06
# 1964                                        1.59218e+06
#
#      Urban population Forest area (sq. km)  \
# 1960      8.78697e+08           2.8688e+07
# 1961      9.01916e+08           2.8688e+07
# 1962      9.27114e+08           2.8688e+07
# 1963      9.54992e+08           2.8688e+07
# 1964      9.83405e+08           2.8688e+07
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent)
# 1960                                             104428
# 1961                                             104428
# 1962                                             104428
# 1963                                             104428
# 1964                                             104428
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Target Vector

# %% [markdown]
# Target vector is global temperature anomaly from 1960 to 2016.

# %%
y_tempe_train = df_tempe_since_1960['annual mean'].values
# y_tempe_train = df_tempe_since_1960['5 year mean'].values
print('Dataframe shape:', y_tempe_train.shape)
y_tempe_train
# Out:
# Dataframe shape: (57,)
# array([-0.02,  0.05,  0.03,  0.06, -0.2 , -0.1 , -0.05, -0.02, -0.07,
#         0.07,  0.02, -0.09,  0.01,  0.15, -0.07, -0.02, -0.11,  0.18,
#         0.07,  0.17,  0.27,  0.33,  0.13,  0.3 ,  0.15,  0.12,  0.19,
#         0.33,  0.41,  0.28,  0.44,  0.43,  0.23,  0.24,  0.32,  0.46,
#         0.35,  0.48,  0.64,  0.42,  0.42,  0.55,  0.63,  0.62,  0.55,
#         0.69,  0.63,  0.66,  0.54,  0.64,  0.71,  0.6 ,  0.63,  0.65,
#         0.74,  0.87,  0.99])

# %% [markdown]
# ### Concat the target to the main matrix

# %%
dataset_tempe['target'] = y_tempe_train
print('Dataframe shape:', dataset_tempe.shape)
dataset_tempe.head()
# Out:
# Dataframe shape: (57, 44)
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                             79.458
# 1961                                             79.458
# 1962                                             79.458
# 1963                                             79.458
# 1964                                             79.458
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                             182.64
# 1961                                             182.64
# 1962                                             182.64
# 1963                                             182.64
# 1964                                             182.64
#
#      Improved water source, urban (% of urban population with access)  \
# 1960                                            98.1536
# 1961                                            98.1536
# 1962                                            98.1536
# 1963                                            98.1536
# 1964                                            98.1536
#
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.47175
# 1961                                  0.47175
# 1962                                  0.47175
# 1963                                  0.47175
# 1964                                  0.47175
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.50179
# 1961                                          4.50179
# 1962                                          4.50179
# 1963                                          4.50179
# 1964                                          4.50179
#
#      Mortality rate, under-5 (per 1,000 live births)  \
# 1960                                         73.7929
# 1961                                         72.1464
# 1962                                         70.5768
# 1963                                         69.0786
# 1964                                         67.5839
#
#      Renewable electricity output (% of total electricity output)  \
# 1960                                            21.8154
# 1961                                            21.8154
# 1962                                            21.8154
# 1963                                            21.8154
# 1964                                            21.8154
#
#      Arable land (% of land area) CO2 emissions (metric tons per capita)  \
# 1960                      23.1082                                5.66017
# 1961                      23.1082                                5.70286
# 1962                      23.0374                                5.84855
# 1963                      22.9832                                6.02533
# 1964                       22.902                                6.23069
#
#      Terrestrial protected areas (% of total land area)  ...    \
# 1960                                            7.80804  ...
# 1961                                            7.80804  ...
# 1962                                            7.80804  ...
# 1963                                            7.80804  ...
# 1964                                            7.80804  ...
#
#      SF6 gas emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                             107782
# 1961                                             107782
# 1962                                             107782
# 1963                                             107782
# 1964                                             107782
#
#      Population, total Agricultural land (sq. km)  \
# 1960       2.40932e+09                3.02061e+07
# 1961        2.4345e+09                3.02061e+07
# 1962       2.47101e+09                3.02598e+07
# 1963       2.51917e+09                3.03205e+07
# 1964        2.5672e+09                3.03669e+07
#
#      Electricity production from renewable sources, excluding hydroelectric (kWh)  \
# 1960                                          3.791e+09
# 1961                                          4.179e+09
# 1962                                          4.548e+09
# 1963                                          5.113e+09
# 1964                                          5.404e+09
#
#      Annual freshwater withdrawals, total (billion cubic meters)  \
# 1960                                             2338.8
# 1961                                             2338.8
# 1962                                             2338.8
# 1963                                             2338.8
# 1964                                             2338.8
#
#      Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.59218e+06
# 1961                                        1.59218e+06
# 1962                                        1.59218e+06
# 1963                                        1.59218e+06
# 1964                                        1.59218e+06
#
#      Urban population Forest area (sq. km)  \
# 1960      8.78697e+08           2.8688e+07
# 1961      9.01916e+08           2.8688e+07
# 1962      9.27114e+08           2.8688e+07
# 1963      9.54992e+08           2.8688e+07
# 1964      9.83405e+08           2.8688e+07
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent) target
# 1960                                             104428          -0.02
# 1961                                             104428           0.05
# 1962                                             104428           0.03
# 1963                                             104428           0.06
# 1964                                             104428          -0.20
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Generating the Model

# %%
from sklearn.linear_model import LinearRegression
lr_tempe = LinearRegression(fit_intercept=True)
lr_tempe.fit(X_tempe_train, y_tempe_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.ensemble import RandomForestRegressor

max_depth = 30
regr_rf = RandomForestRegressor(max_depth=max_depth, random_state=2)
regr_rf.fit(X_tempe_train, y_tempe_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=30,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=2,
#            verbose=0, warm_start=False)

# %%
from sklearn.svm import SVR

svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_rbf.fit(X_tempe_train, y_tempe_train)
# Out:
# SVR(C=1000.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Predict the anomaly temperature

# %%
dataset_tempe['LR prediction'] = lr_tempe.predict(X_tempe_train)
dataset_tempe['RFR prediction'] = regr_rf.predict(X_tempe_train)
dataset_tempe['SVR prediction'] = svr_rbf.predict(X_tempe_train)
print('Dataframe shape:', dataset_tempe.shape)
dataset_tempe.head()
# Out:
# Dataframe shape: (57, 47)
#      Annual freshwater withdrawals, total (% of internal resources)  \
# 1960                                             79.458
# 1961                                             79.458
# 1962                                             79.458
# 1963                                             79.458
# 1964                                             79.458
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)  \
# 1960                                             182.64
# 1961                                             182.64
# 1962                                             182.64
# 1963                                             182.64
# 1964                                             182.64
#
#      Improved water source, urban (% of urban population with access)  \
# 1960                                            98.1536
# 1961                                            98.1536
# 1962                                            98.1536
# 1963                                            98.1536
# 1964                                            98.1536
#
#      CO2 emissions (kg per 2011 PPP $ of GDP)  \
# 1960                                  0.47175
# 1961                                  0.47175
# 1962                                  0.47175
# 1963                                  0.47175
# 1964                                  0.47175
#
#      Marine protected areas (% of territorial waters)  \
# 1960                                          4.50179
# 1961                                          4.50179
# 1962                                          4.50179
# 1963                                          4.50179
# 1964                                          4.50179
#
#      Mortality rate, under-5 (per 1,000 live births)  \
# 1960                                         73.7929
# 1961                                         72.1464
# 1962                                         70.5768
# 1963                                         69.0786
# 1964                                         67.5839
#
#      Renewable electricity output (% of total electricity output)  \
# 1960                                            21.8154
# 1961                                            21.8154
# 1962                                            21.8154
# 1963                                            21.8154
# 1964                                            21.8154
#
#      Arable land (% of land area) CO2 emissions (metric tons per capita)  \
# 1960                      23.1082                                5.66017
# 1961                      23.1082                                5.70286
# 1962                      23.0374                                5.84855
# 1963                      22.9832                                6.02533
# 1964                       22.902                                6.23069
#
#      Terrestrial protected areas (% of total land area)      ...        \
# 1960                                            7.80804      ...
# 1961                                            7.80804      ...
# 1962                                            7.80804      ...
# 1963                                            7.80804      ...
# 1964                                            7.80804      ...
#
#      Electricity production from renewable sources, excluding hydroelectric (kWh)  \
# 1960                                          3.791e+09
# 1961                                          4.179e+09
# 1962                                          4.548e+09
# 1963                                          5.113e+09
# 1964                                          5.404e+09
#
#      Annual freshwater withdrawals, total (billion cubic meters)  \
# 1960                                             2338.8
# 1961                                             2338.8
# 1962                                             2338.8
# 1963                                             2338.8
# 1964                                             2338.8
#
#      Nitrous oxide emissions (thousand metric tons of CO2 equivalent)  \
# 1960                                        1.59218e+06
# 1961                                        1.59218e+06
# 1962                                        1.59218e+06
# 1963                                        1.59218e+06
# 1964                                        1.59218e+06
#
#      Urban population Forest area (sq. km)  \
# 1960      8.78697e+08           2.8688e+07
# 1961      9.01916e+08           2.8688e+07
# 1962      9.27114e+08           2.8688e+07
# 1963      9.54992e+08           2.8688e+07
# 1964      9.83405e+08           2.8688e+07
#
#      PFC gas emissions (thousand metric tons of CO2 equivalent) target  \
# 1960                                             104428          -0.02
# 1961                                             104428           0.05
# 1962                                             104428           0.03
# 1963                                             104428           0.06
# 1964                                             104428          -0.20
#
#      LR prediction RFR prediction SVR prediction
# 1960     -0.026787         -0.013       0.079867
# 1961      0.110803          0.027       0.149867
# 1962     -0.030014          0.034       0.129867
# 1963      0.187881          0.057       0.159867
# 1964     -0.289791         -0.108      -0.100133
#
# [5 rows x 47 columns]

# %%
dataset_tempe[['target', 'LR prediction', 'RFR prediction', 'SVR prediction']].plot(figsize = (16,5), alpha=0.6);

# %% [markdown]
# ## Analysis

# %%
# Recursive Feature Elimination
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

target_int = (dataset_tempe.target*100).astype(int)

# create a base classifier used to evaluate a subset of attributes
RFEmodel = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(RFEmodel, 7)
rfe = rfe.fit(X_tempe_train, target_int) #dataset_tempe.target)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False  True  True  True  True False False
#   True False False  True False  True False]
# [17 13 16 37 27 12 23 24 31 25 29 20  8 11 28 14 26 36 18 34 32 30 35 19 33
#  10 15 22 21  5  1  1  1  1  6  3  1  4  9  1  2  1  7]

# %%
X_tempe_train.columns[rfe.support_]
# Out:
# Index(['Methane emissions (kt of CO2 equivalent)',
#        'Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#        'CO2 emissions (kt)',
#        'Total greenhouse gas emissions (kt of CO2 equivalent)',
#        'Agricultural land (sq. km)',
#        'Nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#        'Forest area (sq. km)'],
#       dtype='object')

# %%
f, axarr = plt.subplots(7, sharex=True)

for i, indi in enumerate(X_tempe_train.columns[rfe.support_]):
    # print(indi)
    axarr[i].plot(dataset_tempe[indi].index, dataset_tempe[indi].values)

# %% [markdown]
# After doing Recrusive Feature Elimination on our dataset, indicators which has most significant contribution to global temperature anomaly can be discovered. We found top seven indicators, which are:
#
# * **Nitrous oxide emissions (thousand metric tons of CO<sub>2</sub> equivalent)**
# <dd> While it contributes only 5 percent of US greenhouse gas emission in 2015. But according to EPA, the impact of 1 pound of N<sub>2</sub>O on warming the atmosphere is almost 300 times that of 1 pound of carbon dioxide [1]. </dd>
#
#
# * **Methane emissions (kt of CO<sub>2</sub> equivalent)**
# <dd> Pound for pound, the comparative impact of CH<sub>4</sub> is more than 25 times greater than CO<sub>2</sub> over a 100-year period [1]. Though it only contributes only 10 percent of US greenhouse gas emission in 2015.</dd>
#
#
# * **Forest area (sq. km)**
# <dd> As described by plot ..... , the trend of forest area in the world is decreasing. It means that deforestation keeps happening around the world. In accordance with World Carfree Network (WCN) [3], deforestation contributes to 15 percent of global carbon dioxide emissions</dd>
#
#
# * **Agricultural land (sq. km)**
# <dd> Agriculture actually contributes to climate change. At every stage of agricultural process, some greenhouse gases are released into atmosphere. For example, Nitrous Oxide is emitted when people use synthetic fertilizers to the soil or domestic livestock such as cattle also produce a large amount of methane </dd>
#
#
# * **Other greenhouse gas emissions, HFC, PFC and SF<sub>6</sub> (thousand metric tons of CO<sub>2</sub> equivalent)**
# <dd> This group of gases is also called Fluorinated gases. Although, it has only small portion around 3 percent [1]. They are  referred to as High Global Warming Potential gases. One of the reason is their ability to deplete stratospheric ozone substances.</dd>
#
#
# * **Total greenhouse gas emissions (kt of CO<sub>2</sub> equivalent)**
# <dd>As known to many people, execessive greenhouse gas emission is the main cause of global warming and conseqeuntly climate change. This effect is caused due to these gases having greenhouse effect, or trapping heat from sunlight in the atmosphere.  The most abundant greenhouse gases in Earth's atmosphere are water vapor, carbon dioxide, methane, nitrous oxide, ozone, chlorofluorocarbons and Hydrofluorocarbons [2].</dd>
#
#
# * **CO<sub>2</sub> emissions (kt)**
# <dd> Carbon dioxide is the primary greenhouse gas emitted by human activites. The main sources are electricity, transportation and Industry [1]. </dd>
#
#
# [1] https://www.epa.gov/ghgemissions/overview-greenhouse-gases
#
# [2] https://en.wikipedia.org/wiki/Greenhouse_gas#Global_warming_potential
#
# [3] https://www.scientificamerican.com/article/deforestation-and-global-warming/

# %% [markdown]
# # Prediction on the Future Condition

# %% [markdown]
# ## Global temperature anomaly in the near future

# %%
y_tempe_train = df_tempe_since_1960['5 year mean'].values
dataset_tempe['5 year'] = y_tempe_train
regr_rf.fit(X_tempe_train, y_tempe_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=30,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=2,
#            verbose=0, warm_start=False)

# %%
dataset_tempe['RFR future prediction'] = regr_rf.predict(X_tempe_train)

# %%
dataset_tempe[['5 year','RFR future prediction']].plot(figsize = (16,5), alpha=0.6);
