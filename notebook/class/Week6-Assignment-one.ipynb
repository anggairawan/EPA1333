# %% [markdown]
# # EPA1333 - Computer Engineering for Scientific Computing
# ## Week 6 - Oct 10, 2017

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Links
#
#   * [Pandas Exercises](https://github.com/guipsamora/pandas_exercises)
#   * [100 pandas puzzles (well incomplete...)](https://github.com/ajcr/100-pandas-puzzles)
#
#   * [Walkthrough exercises from PandasTutorial by Wes McKinney](https://github.com/lemonbalm/pandas-exercises)
#   Note: you need to convert these to Python3 first.
#   * [A few common Excel tasks in Pandas](http://pbpython.com/excel-pandas-comp.html)
#
#   * Some more Tutorials:
#     * https://apawlik.github.io/2014-04-09-GARNET/lessons/garnet/pandas/tutorial.html
#     * http://efavdb.com/pandas-tips-and-tricks/

# %% [markdown]
# # Pandas exercises

# %% [markdown]
# ## Exercise 1: Euro 2012 Football
#
#
# Based on an exercise on [Pandas Exercises](https://github.com/guipsamora/pandas_exercises).

# %% [markdown]
# ### Import data
#
# There Euro 2012 data in the following url
#
# ```
# https://raw.githubusercontent.com/jokecamp/FootballData/master/Euro%202012/Euro%202012%20stats%20TEAM.csv
# ```

# %% [markdown]
# #### Q1: Read the data into a DataFrame.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import random

# %%
import io
import requests
#url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
url = "https://raw.githubusercontent.com/jokecamp/FootballData/master/Euro%202012/Euro%202012%20stats%20TEAM.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
c
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored      ...       \
# 0              0              0                     0      ...
# 1              0              0                     0      ...
# 2              1              0                     0      ...
# 3              0              0                     0      ...
# 4              1              0                     0      ...
# 5              2              1                     0      ...
# 6              1              1                     1      ...
# 7              2              0                     0      ...
# 8              2              0                     0      ...
# 9              0              0                     0      ...
# 10             6              0                     0      ...
# 11             0              0                     0      ...
# 12             2              0                     0      ...
# 13             0              1                     0      ...
# 14             3              0                     0      ...
# 15             0              0                     0      ...
#
#     Saves made  Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  \
# 0           13                 81.3%         41             62         2
# 1            9                 60.1%         53             73         8
# 2           10                 66.7%         25             38         8
# 3           22                 88.1%         43             45         6
# 4            6                 54.6%         36             51         5
# 5           10                 62.6%         63             49        12
# 6           13                 65.1%         67             48        12
# 7           20                 74.1%        101             89        16
# 8           12                 70.6%         35             30         3
# 9            6                 66.7%         48             56         3
# 10          10                 71.5%         73             90        10
# 11          17                 65.4%         43             51        11
# 12          10                 77.0%         34             43         4
# 13          15                 93.8%        102             83        19
# 14           8                 61.6%         35             51         7
# 15          13                 76.5%         48             31         4
#
#     Yellow Cards  Red Cards  Subs on  Subs off  Players Used
# 0              9          0        9         9            16
# 1              7          0       11        11            19
# 2              4          0        7         7            15
# 3              5          0       11        11            16
# 4              6          0       11        11            19
# 5              4          0       15        15            17
# 6              9          1       12        12            20
# 7             16          0       18        18            19
# 8              5          0        7         7            15
# 9              7          1        7         7            17
# 10            12          0       14        14            16
# 11             6          1       10        10            17
# 12             6          0        7         7            16
# 13            11          0       17        17            18
# 14             7          0        9         9            18
# 15             5          0        9         9            18
#
# [16 rows x 35 columns]

# %% [markdown]
# #### Q2:  Show the first 10 lines. Check if your import worked.

# %%
# Your code goes here
c.iloc[ :10 ]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
# 7             7.5%                         110             2              0
# 8             4.1%                          60             2              0
# 9             5.2%                          48             0              0
#
#    Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 0                     0      ...               13                 81.3%
# 1                     0      ...                9                 60.1%
# 2                     0      ...               10                 66.7%
# 3                     0      ...               22                 88.1%
# 4                     0      ...                6                 54.6%
# 5                     0      ...               10                 62.6%
# 6                     1      ...               13                 65.1%
# 7                     0      ...               20                 74.1%
# 8                     0      ...               12                 70.6%
# 9                     0      ...                6                 66.7%
#
#    Fouls Won Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  \
# 0         41             62         2             9          0        9
# 1         53             73         8             7          0       11
# 2         25             38         8             4          0        7
# 3         43             45         6             5          0       11
# 4         36             51         5             6          0       11
# 5         63             49        12             4          0       15
# 6         67             48        12             9          1       12
# 7        101             89        16            16          0       18
# 8         35             30         3             5          0        7
# 9         48             56         3             7          1        7
#
#    Subs off  Players Used
# 0         9            16
# 1        11            19
# 2         7            15
# 3        11            16
# 4        11            19
# 5        15            17
# 6        12            20
# 7        18            19
# 8         7            15
# 9         7            17
#
# [10 rows x 35 columns]

# %% [markdown]
# #### Q3: Show the teams that participated in Euro 2012.

# %%
# Your code goes here
c["Team"]
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %% [markdown]
# #### Q4: How many Teams participated in Euro 2012?

# %%
# Your code goes here
c["Team"].count()
# Out:
# 16

# %% [markdown]
# #### Q5: What are the column names in the dataframe?

# %%
# Your code goes here
c.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %% [markdown]
# #### Q6: Which teams received more than 8 Yellow Cards?

# %%
c["Yellow Cards"] > 8
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# Name: Yellow Cards, dtype: bool

# %%
# Your code goes here
c["Team"][c["Yellow Cards"] > 8]
# Out:
# 0      Croatia
# 6       Greece
# 7        Italy
# 10    Portugal
# 13       Spain
# Name: Team, dtype: object

# %% [markdown]
# #### Q7: How many teams had taken more than 20 corners?

# %%
c["Corners Taken"]
# Out:
# 0     14
# 1     21
# 2     16
# 3     16
# 4     28
# 5     35
# 6     10
# 7     30
# 8     22
# 9     14
# 10    41
# 11     8
# 12    21
# 13    44
# 14     7
# 15    18
# Name: Corners Taken, dtype: int64

# %%
# Your code goes here
c["Team"][c["Corners Taken"] > 20]
# Out:
# 1     Czech Republic
# 4             France
# 5            Germany
# 7              Italy
# 8        Netherlands
# 10          Portugal
# 12            Russia
# 13             Spain
# Name: Team, dtype: object

# %% [markdown]
# #### Q8: Which teams scored with penalty goals and headed goals?

# %%
pg = c["Penalty goals"] > 0
pg
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# Name: Penalty goals, dtype: bool

# %%
hg = c["Headed goals"] > 0
hg
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# Name: Headed goals, dtype: bool

# %%
c["Team"][pg & hg]
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# #### Q9: How many goals were scored in total?

# %%
c
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored      ...       \
# 0              0              0                     0      ...
# 1              0              0                     0      ...
# 2              1              0                     0      ...
# 3              0              0                     0      ...
# 4              1              0                     0      ...
# 5              2              1                     0      ...
# 6              1              1                     1      ...
# 7              2              0                     0      ...
# 8              2              0                     0      ...
# 9              0              0                     0      ...
# 10             6              0                     0      ...
# 11             0              0                     0      ...
# 12             2              0                     0      ...
# 13             0              1                     0      ...
# 14             3              0                     0      ...
# 15             0              0                     0      ...
#
#     Saves made  Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  \
# 0           13                 81.3%         41             62         2
# 1            9                 60.1%         53             73         8
# 2           10                 66.7%         25             38         8
# 3           22                 88.1%         43             45         6
# 4            6                 54.6%         36             51         5
# 5           10                 62.6%         63             49        12
# 6           13                 65.1%         67             48        12
# 7           20                 74.1%        101             89        16
# 8           12                 70.6%         35             30         3
# 9            6                 66.7%         48             56         3
# 10          10                 71.5%         73             90        10
# 11          17                 65.4%         43             51        11
# 12          10                 77.0%         34             43         4
# 13          15                 93.8%        102             83        19
# 14           8                 61.6%         35             51         7
# 15          13                 76.5%         48             31         4
#
#     Yellow Cards  Red Cards  Subs on  Subs off  Players Used
# 0              9          0        9         9            16
# 1              7          0       11        11            19
# 2              4          0        7         7            15
# 3              5          0       11        11            16
# 4              6          0       11        11            19
# 5              4          0       15        15            17
# 6              9          1       12        12            20
# 7             16          0       18        18            19
# 8              5          0        7         7            15
# 9              7          1        7         7            17
# 10            12          0       14        14            16
# 11             6          1       10        10            17
# 12             6          0        7         7            16
# 13            11          0       17        17            18
# 14             7          0        9         9            18
# 15             5          0        9         9            18
#
# [16 rows x 35 columns]

# %%
# Your code goes here
c["Goals"].sum()
# Out:
# 76

# %% [markdown]
# #### Q10: Create a DataFrame which shows the total number of fouls (won and conceded) for each team

# %%
# Your code goes here
c[["Fouls Won", "Fouls Conceded"]]
# Out:
#     Fouls Won  Fouls Conceded
# 0          41              62
# 1          53              73
# 2          25              38
# 3          43              45
# 4          36              51
# 5          63              49
# 6          67              48
# 7         101              89
# 8          35              30
# 9          48              56
# 10         73              90
# 11         43              51
# 12         34              43
# 13        102              83
# 14         35              51
# 15         48              31

# %%
c["Fouls Won"] + c["Fouls Conceded"]
# Out:
# 0     103
# 1     126
# 2      63
# 3      88
# 4      87
# 5     112
# 6     115
# 7     190
# 8      65
# 9     104
# 10    163
# 11     94
# 12     77
# 13    185
# 14     86
# 15     79
# dtype: int64

# %% [markdown]
# #### Q11: View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
# Your code goes here
discipline = c[["Team", "Yellow Cards", "Red Cards"]]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# #### Q12: Sort the discipline dataframe. First on Red Cards, then on Yellow Cards, in descending order

# %%
# Your code goes here
# df.sort_values( by='B', ascending=True )
discipline.sort_values(by = "Red Cards", ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Your code goes here
# df.sort_values( by='B', ascending=True )
discipline.sort_values(by = "Yellow Cards", ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 6                Greece             9          1
# 1        Czech Republic             7          0
# 9                Poland             7          1
# 14               Sweden             7          0
# 4                France             6          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# #### Q13: What is the average amount of Yellow Cards?

# %%
# Your code goes here
# s.rank(method='average')
discipline["Yellow Cards"].mean()
# Out:
# 7.4375

# %% [markdown]
# #### Q14: Print the teams that start with the letter 'G'.
#
# *Hint:* Series (such as a column of a DataFrame) also support string operations.
# If s is a series then:
# ```
#     s.str
# ```
# provides access to all types of common string operations (such as, contains, islower, len, slice, strip, split, startswith, etc).
#
# See ```help pd.Series.str``` for more information.

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
# Your code goes here
c["Team"][c["Team"].str.contains("G")]
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %% [markdown]
# #### Q15: Plot a bar chart showing the Shooting Accuracy of each Team.
#
# *Hint*: Shooting Accuracy is a string. To plot these values, they must be a number. You can use
# ```
#     dataframe['column'].astype(type)
# ```
# to change the type of the values in a column to a given type. Note however, that you first need to
# strip off the '%'-sign from the string before the conversion can succeed.
#
# *Hint*: Create a new column with the shooting accuracy values as a real float. Then use the plot() method
# of the dataframe to plot the shooting accuracy as a bar chart. Use the Team names to name the bars.

# %%
# Your code goes here
c_strip_percent = c["Shooting Accuracy"].str.strip('%')

c_float = c_strip_percent.astype(float)

# %%
sa_plot = c_float.plot(kind="bar", width = 0.8, color = 'red', title="Shooting Accuracy")
sa_plot.set_xlabel("Teams")
sa_plot.set_ylabel("%")
sa_plot.set_xticklabels(c.Team, rotation=90)
# Out:
# [<matplotlib.text.Text at 0x1ffeff62198>,
#  <matplotlib.text.Text at 0x1fff000f278>,
#  <matplotlib.text.Text at 0x1ffefdbf358>,
#  <matplotlib.text.Text at 0x1ffefdc76d8>,
#  <matplotlib.text.Text at 0x1ffefdd8be0>,
#  <matplotlib.text.Text at 0x1ffefdd8128>,
#  <matplotlib.text.Text at 0x1ffeffe89e8>,
#  <matplotlib.text.Text at 0x1ffeffd7c50>,
#  <matplotlib.text.Text at 0x1fff000f3c8>,
#  <matplotlib.text.Text at 0x1fff0299d68>,
#  <matplotlib.text.Text at 0x1ffefddd9b0>,
#  <matplotlib.text.Text at 0x1ffefddd8d0>,
#  <matplotlib.text.Text at 0x1ffefd45ef0>,
#  <matplotlib.text.Text at 0x1ffefd68128>,
#  <matplotlib.text.Text at 0x1ffefd68550>,
#  <matplotlib.text.Text at 0x1ffeffeef98>]
